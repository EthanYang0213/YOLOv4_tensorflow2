# %% [markdown]
# # 計算模型mAP
# - 本文使用VOC格式进行评估。
# - 评估前将标签文件放在VOCdevkit文件夹下的VOC2007文件夹下的Annotation中。
# - 评估前将图片文件放在VOCdevkit文件夹下的VOC2007文件夹下的JPEGImages中。
# - 在评估前利用voc2yolo4.py文件生成对应的txt，评估用的txt为VOCdevkit/VOC2007/ImageSets/Main/test.txt，需要注意的是，如果整个VOC2007里面的数据集都是用于评估，那么直接将trainval_percent设置成0即可。
# - 在yolo.py文件里面，在如下部分修改model_path和classes_path使其对应训练好的文件；model_path对应logs文件夹下面的权值文件，classes_path是model_path对应分的类。
# - 运行get_dr_txt.py和get_gt_txt.py，在./input/detection-results和./input/ground-truth文件夹下生成对应的txt。
# - 运行get_map.py即可开始计算模型的mAP。
# - 若使用coco預訓練模型的話要在get_dr_txt.py中設定要偵測的類別

# %%
# 將直接生成的test.txt(有標註資料)轉為單純ID資料的test.txt檔供測試使用
# import re
# pattern = r'(\/\w+\/\w+\/)(.*\.\w+)'
# f = open('test.txt')
# path = 'output.txt'
# ff = open(path, 'w')
# for line in f.readlines():
#     ff.write(re.search(pattern, line, flags=0).group(2)+'\n')
# ff.close()
# f.close()

# %%
# get_dr_txt.py
#----------------------------------------------------#
#   获取测试集的detection-result和images-optional
#   具体视频教程可查看
#   https://www.bilibili.com/video/BV1zE411u7Vw
#----------------------------------------------------#
import colorsys
import os

import numpy as np
import tensorflow as tf
from PIL import Image
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Lambda
from tensorflow.keras.models import Model
from tqdm import tqdm

from nets.yolo4 import yolo_body, yolo_eval
from utils.utils import letterbox_image
from yolo import YOLO

'''
这里设置的门限值较低是因为计算map需要用到不同门限条件下的Recall和Precision值。
所以只有保留的框足够多，计算的map才会更精确，详情可以了解map的原理。
计算map时输出的Recall和Precision值指的是门限为0.5时的Recall和Precision值。
此处获得的./input/detection-results/里面的txt的框的数量会比直接predict多一些，这是因为这里的门限低，
目的是为了计算不同门限条件下的Recall和Precision值，从而实现map的计算。
这里的self.iou指的是非极大抑制所用到的iou，具体的可以了解非极大抑制的原理，
如果低分框与高分框的iou大于这里设定的self.iou，那么该低分框将会被剔除。
可能有些同学知道有0.5和0.5:0.95的mAP，这里的self.iou=0.5不代表mAP0.5。
如果想要设定mAP0.x，比如设定mAP0.75，可以去get_map.py设定MINOVERLAP。
'''
# gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
# for gpu in gpus:
#     tf.config.experimental.set_memory_growth(gpu, True)

class mAP_YOLO(YOLO):
    #---------------------------------------------------#
    #   获得所有的分类
    #---------------------------------------------------#
    def generate(self):
        self.score = 0.01
        self.iou = 0.5
        model_path = os.path.expanduser(self.model_path)
        assert model_path.endswith('.h5'), 'Keras model or weights must be a .h5 file.'
        
        #---------------------------------------------------#
        #   计算先验框的数量和种类的数量
        #---------------------------------------------------#
        num_anchors = len(self.anchors)
        num_classes = len(self.class_names)

        #---------------------------------------------------------#
        #   载入模型
        #---------------------------------------------------------#
        self.yolo_model = yolo_body(Input(shape=(None,None,3)), num_anchors//3, num_classes)
        self.yolo_model.load_weights(self.model_path)

        print('{} model, anchors, and classes loaded.'.format(model_path))

        # 画框设置不同的颜色
        hsv_tuples = [(x / len(self.class_names), 1., 1.)
                      for x in range(len(self.class_names))]
        self.colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
        self.colors = list(
            map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)),
                self.colors))

        # 打乱颜色
        np.random.seed(10101)
        np.random.shuffle(self.colors)
        np.random.seed(None)

        #---------------------------------------------------------#
        #   在yolo_eval函数中，我们会对预测结果进行后处理
        #   后处理的内容包括，解码、非极大抑制、门限筛选等
        #---------------------------------------------------------#
        self.input_image_shape = Input([2,],batch_size=1)
        inputs = [*self.yolo_model.output, self.input_image_shape]
        outputs = Lambda(yolo_eval, output_shape=(1,), name='yolo_eval',
            arguments={'anchors': self.anchors, 'num_classes': len(self.class_names), 'image_shape': self.model_image_size, 
            'score_threshold': self.score, 'eager': True, 'max_boxes': self.max_boxes, 'letterbox_image': self.letterbox_image})(inputs)
        self.yolo_model = Model([self.yolo_model.input, self.input_image_shape], outputs)

    #---------------------------------------------------#
    #   检测图片
    #---------------------------------------------------#
    def detect_image(self, image_id, image):
        f = open("./input/detection-results/"+image_id+".txt","w") 
        #---------------------------------------------------------#
        #   给图像增加灰条，实现不失真的resize
        #   也可以直接resize进行识别
        #---------------------------------------------------------#
        if self.letterbox_image:
            boxed_image = letterbox_image(image, (self.model_image_size[1],self.model_image_size[0]))
        else:
            boxed_image = image.convert('RGB')
            boxed_image = boxed_image.resize((self.model_image_size[1],self.model_image_size[0]), Image.BICUBIC)
        image_data = np.array(boxed_image, dtype='float32')
        image_data /= 255.
        #---------------------------------------------------------#
        #   添加上batch_size维度
        #---------------------------------------------------------#
        image_data = np.expand_dims(image_data, 0)  # Add batch dimension.

        #---------------------------------------------------------#
        #   将图像输入网络当中进行预测！
        #---------------------------------------------------------#
        input_image_shape = np.expand_dims(np.array([image.size[1], image.size[0]], dtype='float32'), 0)
        out_boxes, out_scores, out_classes = self.get_pred(image_data, input_image_shape) 
        
        for i, c in enumerate(out_classes):
            predicted_class = self.class_names[int(c)]
            try:
                score = str(out_scores[i].numpy())
            except:
                score = str(out_scores[i])
            top, left, bottom, right = out_boxes[i]
            f.write("%s %s %s %s %s %s\n" % (predicted_class, score[:6], str(int(left)), str(int(top)), str(int(right)),str(int(bottom))))
           
            # 篩選類別
#             if predicted_class == 'person':
#                 f.write("%s %s %s %s %s %s\n" % (predicted_class, score[:6], str(int(left)), str(int(top)), str(int(right)),str(int(bottom))))

        f.close()
        return 

yolo = mAP_YOLO()

# 設定test.txt的路徑, 要取得測試集的各圖片ID
# 此test.txt為單純ID, 沒有標註資料
image_ids = open('VOCdevkit/VOC2007/ImageSets/Main/test.txt').read().strip().split()

if not os.path.exists("./input"):
    os.makedirs("./input")
if not os.path.exists("./input/detection-results"):
    os.makedirs("./input/detection-results")
if not os.path.exists("./input/images-optional"):
    os.makedirs("./input/images-optional")

for image_id in tqdm(image_ids):
#     image_path = "./VOCdevkit/VOC2007/JPEGImages/"+image_id+".jpg"
    image_path = "./VOCdevkit/VOC2007/JPEGImages/"+image_id
    image = Image.open(image_path)
    # 开启后在之后计算mAP可以可视化
    image.save("./input/images-optional/"+image_id)
    yolo.detect_image(image_id,image)
    
print("Conversion completed!")
# Out:
# model_data/INRIA_final.h5 model, anchors, and classes loaded.
# 100%|████████████████████████████████████████████████████████████████████████████████| 741/741 [19:48<00:00,  1.60s/it]
# Conversion completed!

# %%
# 若detection_results中的檔名格式多了.png/jpg等
# 再處理調僅留下圖片ID.txt
import os
path = 'input/detection-results/'
for fname in os.listdir(path):
    print(os.path.join(path, fname))
    new_fname = fname[:-8]+'.txt'
    print(new_fname)
    os.rename(os.path.join(path, fname), os.path.join(path, new_fname))
# Out:
# input/detection-results/00001147.png.txt
# 00001147.txt
# input/detection-results/00001148.png.txt
# 00001148.txt
# input/detection-results/00001149.png.txt
# 00001149.txt
# input/detection-results/00001150.png.txt
# 00001150.txt
# input/detection-results/00001153.png.txt
# 00001153.txt
# input/detection-results/00001154.png.txt
# 00001154.txt
# input/detection-results/00001155.png.txt
# 00001155.txt
# input/detection-results/00001156.png.txt
# 00001156.txt
# input/detection-results/00001157.png.txt
# 00001157.txt
# input/detection-results/00001158.png.txt
# 00001158.txt
# input/detection-results/00001159.png.txt
# 00001159.txt
# input/detection-results/00001160.png.txt
# 00001160.txt
# input/detection-results/00001161.png.txt
# 00001161.txt
# input/detection-results/00001162.png.txt
# 00001162.txt
# input/detection-results/00001163.png.txt
# 00001163.txt
# input/detection-results/00001165.png.txt
# 00001165.txt
# input/detection-results/00001166.png.txt
# 00001166.txt
# input/detection-results/00001167.png.txt
# 00001167.txt
# input/detection-results/00001168.png.txt
# 00001168.txt
# input/detection-results/00001169.png.txt
# 00001169.txt
# input/detection-results/00001170.png.txt
# 00001170.txt
# input/detection-results/00001171.png.txt
# 00001171.txt
# input/detection-results/00001172.png.txt
# 00001172.txt
# input/detection-results/00001173.png.txt
# 00001173.txt
# input/detection-results/00001176.png.txt
# 00001176.txt
# input/detection-results/00001177.png.txt
# 00001177.txt
# input/detection-results/00001178.png.txt
# 00001178.txt
# input/detection-results/00001179.png.txt
# 00001179.txt
# input/detection-results/00001180.png.txt
# 00001180.txt
# input/detection-results/00001181.png.txt
# 00001181.txt
# input/detection-results/00001192.png.txt
# 00001192.txt
# input/detection-results/00001193.png.txt
# 00001193.txt
# input/detection-results/00001194.png.txt
# 00001194.txt
# input/detection-results/00001202.png.txt
# 00001202.txt
# input/detection-results/00001203.png.txt
# 00001203.txt
# input/detection-results/00001204.png.txt
# 00001204.txt
# input/detection-results/00001205.png.txt
# 00001205.txt
# input/detection-results/00001207.png.txt
# 00001207.txt
# input/detection-results/00001208.png.txt
# 00001208.txt
# input/detection-results/00001209.png.txt
# 00001209.txt
# input/detection-results/00001210.png.txt
# 00001210.txt
# input/detection-results/00001211.png.txt
# 00001211.txt
# input/detection-results/00001212.png.txt
# 00001212.txt
# input/detection-results/00001214.png.txt
# 00001214.txt
# input/detection-results/00001215.png.txt
# 00001215.txt
# input/detection-results/00001216.png.txt
# 00001216.txt
# input/detection-results/00001217.png.txt
# 00001217.txt
# input/detection-results/00001218.png.txt
# 00001218.txt
# input/detection-results/00001219.png.txt
# 00001219.txt
# input/detection-results/00001220.png.txt
# 00001220.txt
# input/detection-results/00001221.png.txt
# 00001221.txt
# input/detection-results/00001222.png.txt
# 00001222.txt
# input/detection-results/00001223.png.txt
# 00001223.txt
# input/detection-results/00001224.png.txt
# 00001224.txt
# input/detection-results/00001225.png.txt
# 00001225.txt
# input/detection-results/00001226.png.txt
# 00001226.txt
# input/detection-results/00001227.png.txt
# 00001227.txt
# input/detection-results/00001228.png.txt
# 00001228.txt
# input/detection-results/00001231.png.txt
# 00001231.txt
# input/detection-results/00001232.png.txt
# 00001232.txt
# input/detection-results/00001233.png.txt
# 00001233.txt
# input/detection-results/00001234.png.txt
# 00001234.txt
# input/detection-results/00001236.png.txt
# 00001236.txt
# input/detection-results/00001240.png.txt
# 00001240.txt
# input/detection-results/00001241.png.txt
# 00001241.txt
# input/detection-results/00001242.png.txt
# 00001242.txt
# input/detection-results/00001243.png.txt
# 00001243.txt
# input/detection-results/00001247.png.txt
# 00001247.txt
# input/detection-results/00001249.png.txt
# 00001249.txt
# input/detection-results/00001250.png.txt
# 00001250.txt
# input/detection-results/00001251.png.txt
# 00001251.txt
# input/detection-results/00001253.png.txt
# 00001253.txt
# input/detection-results/00001254.png.txt
# 00001254.txt
# input/detection-results/00001255.png.txt
# 00001255.txt
# input/detection-results/00001256.png.txt
# 00001256.txt
# input/detection-results/00001257.png.txt
# 00001257.txt
# input/detection-results/00001258.png.txt
# 00001258.txt
# input/detection-results/00001259.png.txt
# 00001259.txt
# input/detection-results/00001260.png.txt
# 00001260.txt
# input/detection-results/00001262.png.txt
# 00001262.txt
# input/detection-results/00001263.png.txt
# 00001263.txt
# input/detection-results/00001265.png.txt
# 00001265.txt
# input/detection-results/00001269.png.txt
# 00001269.txt
# input/detection-results/00001270.png.txt
# 00001270.txt
# input/detection-results/00001271.png.txt
# 00001271.txt
# input/detection-results/00001272.png.txt
# 00001272.txt
# input/detection-results/00001273.png.txt
# 00001273.txt
# input/detection-results/00001279.png.txt
# 00001279.txt
# input/detection-results/00001280.png.txt
# 00001280.txt
# input/detection-results/00001292.png.txt
# 00001292.txt
# input/detection-results/00001293.png.txt
# 00001293.txt
# input/detection-results/00001294.png.txt
# 00001294.txt
# input/detection-results/00001301.png.txt
# 00001301.txt
# input/detection-results/00001304.png.txt
# 00001304.txt
# input/detection-results/00001305.png.txt
# 00001305.txt
# input/detection-results/00001307.png.txt
# 00001307.txt
# input/detection-results/00001308.png.txt
# 00001308.txt
# input/detection-results/00001309.png.txt
# 00001309.txt
# input/detection-results/00001319.png.txt
# 00001319.txt
# input/detection-results/00001324.png.txt
# 00001324.txt
# input/detection-results/00001325.png.txt
# 00001325.txt
# input/detection-results/00001326.png.txt
# 00001326.txt
# input/detection-results/00001327.png.txt
# 00001327.txt
# input/detection-results/00001328.png.txt
# 00001328.txt
# input/detection-results/00001329.png.txt
# 00001329.txt
# input/detection-results/00001330.png.txt
# 00001330.txt
# input/detection-results/00001331.png.txt
# 00001331.txt
# input/detection-results/00001332.png.txt
# 00001332.txt
# input/detection-results/00001335.png.txt
# 00001335.txt
# input/detection-results/00001337.png.txt
# 00001337.txt
# input/detection-results/00001338.png.txt
# 00001338.txt
# input/detection-results/00001342.png.txt
# 00001342.txt
# input/detection-results/00001343.png.txt
# 00001343.txt
# input/detection-results/00001344.png.txt
# 00001344.txt
# input/detection-results/00001348.png.txt
# 00001348.txt
# input/detection-results/00001349.png.txt
# 00001349.txt
# input/detection-results/00001350.png.txt
# 00001350.txt
# input/detection-results/00001352.png.txt
# 00001352.txt
# input/detection-results/00001353.png.txt
# 00001353.txt
# input/detection-results/00001354.png.txt
# 00001354.txt
# input/detection-results/00001355.png.txt
# 00001355.txt
# input/detection-results/00001356.png.txt
# 00001356.txt
# input/detection-results/00001358.png.txt
# 00001358.txt
# input/detection-results/00001361.png.txt
# 00001361.txt
# input/detection-results/00001362.png.txt
# 00001362.txt
# input/detection-results/00001369.png.txt
# 00001369.txt
# input/detection-results/00001370.png.txt
# 00001370.txt
# input/detection-results/00001371.png.txt
# 00001371.txt
# input/detection-results/00001372.png.txt
# 00001372.txt
# input/detection-results/00001373.png.txt
# 00001373.txt
# input/detection-results/00001374.png.txt
# 00001374.txt
# input/detection-results/00001375.png.txt
# 00001375.txt
# input/detection-results/00001376.png.txt
# 00001376.txt
# input/detection-results/00001377.png.txt
# 00001377.txt
# input/detection-results/00001378.png.txt
# 00001378.txt
# input/detection-results/00001379.png.txt
# 00001379.txt
# input/detection-results/00001380.png.txt
# 00001380.txt
# input/detection-results/00001381.png.txt
# 00001381.txt
# input/detection-results/00001382.png.txt
# 00001382.txt
# input/detection-results/00001383.png.txt
# 00001383.txt
# input/detection-results/00001385.png.txt
# 00001385.txt
# input/detection-results/00001386.png.txt
# 00001386.txt
# input/detection-results/00001387.png.txt
# 00001387.txt
# input/detection-results/00001388.png.txt
# 00001388.txt
# input/detection-results/00001389.png.txt
# 00001389.txt
# input/detection-results/00001390.png.txt
# 00001390.txt
# input/detection-results/00001391.png.txt
# 00001391.txt
# input/detection-results/00001392.png.txt
# 00001392.txt
# input/detection-results/00001393.png.txt
# 00001393.txt
# input/detection-results/00001394.png.txt
# 00001394.txt
# input/detection-results/00001395.png.txt
# 00001395.txt
# input/detection-results/00001396.png.txt
# 00001396.txt
# input/detection-results/00001401.png.txt
# 00001401.txt
# input/detection-results/00001402.png.txt
# 00001402.txt
# input/detection-results/00001405.png.txt
# 00001405.txt
# input/detection-results/00001406.png.txt
# 00001406.txt
# input/detection-results/00001407.png.txt
# 00001407.txt
# input/detection-results/00001408.png.txt
# 00001408.txt
# input/detection-results/00001409.png.txt
# 00001409.txt
# input/detection-results/00001410.png.txt
# 00001410.txt
# input/detection-results/00001411.png.txt
# 00001411.txt
# input/detection-results/00001412.png.txt
# 00001412.txt
# input/detection-results/00001413.png.txt
# 00001413.txt
# input/detection-results/00001414.png.txt
# 00001414.txt
# input/detection-results/00001415.png.txt
# 00001415.txt
# input/detection-results/00001416.png.txt
# 00001416.txt
# input/detection-results/00001417.png.txt
# 00001417.txt
# input/detection-results/00001418.png.txt
# 00001418.txt
# input/detection-results/00001419.png.txt
# 00001419.txt
# input/detection-results/00001420.png.txt
# 00001420.txt
# input/detection-results/00001421.png.txt
# 00001421.txt
# input/detection-results/00001422.png.txt
# 00001422.txt
# input/detection-results/00001425.png.txt
# 00001425.txt
# input/detection-results/00001427.png.txt
# 00001427.txt
# input/detection-results/00001431.png.txt
# 00001431.txt
# input/detection-results/00001432.png.txt
# 00001432.txt
# input/detection-results/00001433.png.txt
# 00001433.txt
# input/detection-results/00001434.png.txt
# 00001434.txt
# input/detection-results/00001435.png.txt
# 00001435.txt
# input/detection-results/00001436.png.txt
# 00001436.txt
# input/detection-results/00001437.png.txt
# 00001437.txt
# input/detection-results/00001438.png.txt
# 00001438.txt
# input/detection-results/00001439.png.txt
# 00001439.txt
# input/detection-results/00001440.png.txt
# 00001440.txt
# input/detection-results/00001441.png.txt
# 00001441.txt
# input/detection-results/00001442.png.txt
# 00001442.txt
# input/detection-results/00001443.png.txt
# 00001443.txt
# input/detection-results/00001444.png.txt
# 00001444.txt
# input/detection-results/00001445.png.txt
# 00001445.txt
# input/detection-results/00001447.png.txt
# 00001447.txt
# input/detection-results/00001448.png.txt
# 00001448.txt
# input/detection-results/00001449.png.txt
# 00001449.txt
# input/detection-results/00001450.png.txt
# 00001450.txt
# input/detection-results/00001452.png.txt
# 00001452.txt
# input/detection-results/00001453.png.txt
# 00001453.txt
# input/detection-results/00001454.png.txt
# 00001454.txt
# input/detection-results/00001455.png.txt
# 00001455.txt
# input/detection-results/00001456.png.txt
# 00001456.txt
# input/detection-results/00001457.png.txt
# 00001457.txt
# input/detection-results/00001459.png.txt
# 00001459.txt
# input/detection-results/01-03f.jpg.txt
# 01-03f.txt
# input/detection-results/bike_003.png.txt
# bike_003.txt
# input/detection-results/bike_006.png.txt
# bike_006.txt
# input/detection-results/bike_009.png.txt
# bike_009.txt
# input/detection-results/bike_012.png.txt
# bike_012.txt
# input/detection-results/bike_015.png.txt
# bike_015.txt
# input/detection-results/bike_018.png.txt
# bike_018.txt
# input/detection-results/bike_021.png.txt
# bike_021.txt
# input/detection-results/bike_024.png.txt
# bike_024.txt
# input/detection-results/bike_027.png.txt
# bike_027.txt
# input/detection-results/bike_030.png.txt
# bike_030.txt
# input/detection-results/crop001501.png.txt
# crop001501.txt
# input/detection-results/crop001504.png.txt
# crop001504.txt
# input/detection-results/crop001511.png.txt
# crop001511.txt
# input/detection-results/crop001512.png.txt
# crop001512.txt
# input/detection-results/crop001514.png.txt
# crop001514.txt
# input/detection-results/crop001520.png.txt
# crop001520.txt
# input/detection-results/crop001521.png.txt
# crop001521.txt
# input/detection-results/crop001522.png.txt
# crop001522.txt
# input/detection-results/crop001531.png.txt
# crop001531.txt
# input/detection-results/crop001533.png.txt
# crop001533.txt
# input/detection-results/crop001544.png.txt
# crop001544.txt
# input/detection-results/crop001545.png.txt
# crop001545.txt
# input/detection-results/crop001546.png.txt
# crop001546.txt
# input/detection-results/crop001549.png.txt
# crop001549.txt
# input/detection-results/crop001555.png.txt
# crop001555.txt
# input/detection-results/crop001566.png.txt
# crop001566.txt
# input/detection-results/crop001573.png.txt
# crop001573.txt
# input/detection-results/crop001574.png.txt
# crop001574.txt
# input/detection-results/crop001590.png.txt
# crop001590.txt
# input/detection-results/crop001593.png.txt
# crop001593.txt
# input/detection-results/crop001602.png.txt
# crop001602.txt
# input/detection-results/crop001604.png.txt
# crop001604.txt
# input/detection-results/crop001607.png.txt
# crop001607.txt
# input/detection-results/crop001631.png.txt
# crop001631.txt
# input/detection-results/crop001633.png.txt
# crop001633.txt
# input/detection-results/crop001634.png.txt
# crop001634.txt
# input/detection-results/crop001638.png.txt
# crop001638.txt
# input/detection-results/crop001639.png.txt
# crop001639.txt
# input/detection-results/crop001641.png.txt
# crop001641.txt
# input/detection-results/crop001653.png.txt
# crop001653.txt
# input/detection-results/crop001654.png.txt
# crop001654.txt
# input/detection-results/crop001658.png.txt
# crop001658.txt
# input/detection-results/crop001659.png.txt
# crop001659.txt
# input/detection-results/crop001660.png.txt
# crop001660.txt
# input/detection-results/crop001661.png.txt
# crop001661.txt
# input/detection-results/crop001664.png.txt
# crop001664.txt
# input/detection-results/crop001670.png.txt
# crop001670.txt
# input/detection-results/crop001676.png.txt
# crop001676.txt
# input/detection-results/crop001682.png.txt
# crop001682.txt
# input/detection-results/crop001683.png.txt
# crop001683.txt
# input/detection-results/crop001684.png.txt
# crop001684.txt
# input/detection-results/crop001688.png.txt
# crop001688.txt
# input/detection-results/crop001704.png.txt
# crop001704.txt
# input/detection-results/crop001706.png.txt
# crop001706.txt
# input/detection-results/crop001715.png.txt
# crop001715.txt
# input/detection-results/crop001716.png.txt
# crop001716.txt
# input/detection-results/crop001718.png.txt
# crop001718.txt
# input/detection-results/crop001719.png.txt
# crop001719.txt
# input/detection-results/crop001722.png.txt
# crop001722.txt
# input/detection-results/crop001723.png.txt
# crop001723.txt
# input/detection-results/crop001724.png.txt
# crop001724.txt
# input/detection-results/crop001725.png.txt
# crop001725.txt
# input/detection-results/crop_000001.png.txt
# crop_000001.txt
# input/detection-results/crop_000002.png.txt
# crop_000002.txt
# input/detection-results/crop_000003.png.txt
# crop_000003.txt
# input/detection-results/crop_000004.png.txt
# crop_000004.txt
# input/detection-results/crop_000005.png.txt
# crop_000005.txt
# input/detection-results/crop_000006.png.txt
# crop_000006.txt
# input/detection-results/crop_000007.png.txt
# crop_000007.txt
# input/detection-results/crop_000008.png.txt
# crop_000008.txt
# input/detection-results/crop_000009.png.txt
# crop_000009.txt
# input/detection-results/crop_000012.png.txt
# crop_000012.txt
# input/detection-results/crop_000013.png.txt
# crop_000013.txt
# input/detection-results/crop_000015.png.txt
# crop_000015.txt
# input/detection-results/crop_000016.png.txt
# crop_000016.txt
# input/detection-results/crop_000017.png.txt
# crop_000017.txt
# input/detection-results/crop_000018.png.txt
# crop_000018.txt
# input/detection-results/crop_000019.png.txt
# crop_000019.txt
# input/detection-results/crop_000020.png.txt
# crop_000020.txt
# input/detection-results/crop_000021.png.txt
# crop_000021.txt
# input/detection-results/crop_000023.png.txt
# crop_000023.txt
# input/detection-results/crop_000024.png.txt
# crop_000024.txt
# input/detection-results/crop_000025.png.txt
# crop_000025.txt
# input/detection-results/crop_000026.png.txt
# crop_000026.txt
# input/detection-results/crop_000027.png.txt
# crop_000027.txt
# input/detection-results/crop_000604.png.txt
# crop_000604.txt
# input/detection-results/D2004-01-03_17h26m13s.jpg.txt
# D2004-01-03_17h26m13s.txt
# input/detection-results/D2004-01-04_17h01m28s.jpg.txt
# D2004-01-04_17h01m28s.txt
# input/detection-results/D2004-01-24_16h17m48s.jpg.txt
# D2004-01-24_16h17m48s.txt
# input/detection-results/D2004-03-12_11h12m05s.jpg.txt
# D2004-03-12_11h12m05s.txt
# input/detection-results/D2004-03-12_11h55m08s.jpg.txt
# D2004-03-12_11h55m08s.txt
# input/detection-results/D2004-03-12_14h48m42s.jpg.txt
# D2004-03-12_14h48m42s.txt
# input/detection-results/D2004-03-12_17h50m02s.jpg.txt
# D2004-03-12_17h50m02s.txt
# input/detection-results/D2004-04-11_11h51m15s.jpg.txt
# D2004-04-11_11h51m15s.txt
# input/detection-results/D2004-04-11_13h54m18s.jpg.txt
# D2004-04-11_13h54m18s.txt
# input/detection-results/D2004-04-11_14h01m45s.jpg.txt
# D2004-04-11_14h01m45s.txt
# input/detection-results/D2004-04-11_14h09m24s.jpg.txt
# D2004-04-11_14h09m24s.txt
# input/detection-results/D2004-04-25_12h04m32s.jpg.txt
# D2004-04-25_12h04m32s.txt
# input/detection-results/D2004-04-25_14h40m04s.jpg.txt
# D2004-04-25_14h40m04s.txt
# input/detection-results/D2004-05-08_10h26m52s.jpg.txt
# D2004-05-08_10h26m52s.txt
# input/detection-results/D2004-05-10_16h22m42s.jpg.txt
# D2004-05-10_16h22m42s.txt
# input/detection-results/D2004-05-10_18h03m03s.jpg.txt
# D2004-05-10_18h03m03s.txt
# input/detection-results/D2004-05-10_18h36m17s.jpg.txt
# D2004-05-10_18h36m17s.txt
# input/detection-results/D2004-05-11_18h44m38s.jpg.txt
# D2004-05-11_18h44m38s.txt
# input/detection-results/D2004-05-11_21h37m10s.jpg.txt
# D2004-05-11_21h37m10s.txt
# input/detection-results/D2004-05-12_18h05m32s.jpg.txt
# D2004-05-12_18h05m32s.txt
# input/detection-results/D2004-05-14_13h25m18s.jpg.txt
# D2004-05-14_13h25m18s.txt
# input/detection-results/D2004-05-14_19h36m25s.jpg.txt
# D2004-05-14_19h36m25s.txt
# input/detection-results/D2004-05-14_19h43m31s.jpg.txt
# D2004-05-14_19h43m31s.txt
# input/detection-results/D2004-05-16_10h02m38s.jpg.txt
# D2004-05-16_10h02m38s.txt
# input/detection-results/D2004-05-16_11h23m43s.jpg.txt
# D2004-05-16_11h23m43s.txt
# input/detection-results/D2004-05-16_11h41m51s.jpg.txt
# D2004-05-16_11h41m51s.txt
# input/detection-results/D2004-05-16_11h43m48s.jpg.txt
# D2004-05-16_11h43m48s.txt
# input/detection-results/D2004-05-16_13h58m11s.jpg.txt
# D2004-05-16_13h58m11s.txt
# input/detection-results/D2004-05-16_15h52m20s.jpg.txt
# D2004-05-16_15h52m20s.txt
# input/detection-results/D2004-05-16_19h11m16s.jpg.txt
# D2004-05-16_19h11m16s.txt
# input/detection-results/D2004-05-30_10h50m43s.jpg.txt
# D2004-05-30_10h50m43s.txt
# input/detection-results/D2004-05-30_12h07m51s.jpg.txt
# D2004-05-30_12h07m51s.txt
# input/detection-results/D2004-05-30_14h08m24s.jpg.txt
# D2004-05-30_14h08m24s.txt
# input/detection-results/D2004-06-28_00h53m14s.jpg.txt
# D2004-06-28_00h53m14s.txt
# input/detection-results/D2004-07-06_09h14m47s.jpg.txt
# D2004-07-06_09h14m47s.txt
# input/detection-results/D2004-07-06_09h22m45s.jpg.txt
# D2004-07-06_09h22m45s.txt
# input/detection-results/D2004-07-06_11h10m42s.jpg.txt
# D2004-07-06_11h10m42s.txt
# input/detection-results/D2004-07-06_11h50m53s.jpg.txt
# D2004-07-06_11h50m53s.txt
# input/detection-results/D2004-07-06_13h56m23s.jpg.txt
# D2004-07-06_13h56m23s.txt
# input/detection-results/D2004-07-06_13h59m38s.jpg.txt
# D2004-07-06_13h59m38s.txt
# input/detection-results/D2004-07-06_14h00m20s.jpg.txt
# D2004-07-06_14h00m20s.txt
# input/detection-results/D2004-07-06_14h59m24s.jpg.txt
# D2004-07-06_14h59m24s.txt
# input/detection-results/D2004-07-07_04h31m36s.jpg.txt
# D2004-07-07_04h31m36s.txt
# input/detection-results/D2004-07-07_04h40m20s.jpg.txt
# D2004-07-07_04h40m20s.txt
# input/detection-results/D2004-07-07_07h46m43s.jpg.txt
# D2004-07-07_07h46m43s.txt
# input/detection-results/D2004-07-08_05h01m32s.jpg.txt
# D2004-07-08_05h01m32s.txt
# input/detection-results/D2004-07-08_23h18m59s.jpg.txt
# D2004-07-08_23h18m59s.txt
# input/detection-results/D2004-07-08_23h27m44s.jpg.txt
# D2004-07-08_23h27m44s.txt
# input/detection-results/D2004-07-08_23h55m07s.jpg.txt
# D2004-07-08_23h55m07s.txt
# input/detection-results/D2004-07-09_01h05m35s.jpg.txt
# D2004-07-09_01h05m35s.txt
# input/detection-results/D2004-07-09_17h00m44s.jpg.txt
# D2004-07-09_17h00m44s.txt
# input/detection-results/D2004-07-09_18h11m16s.jpg.txt
# D2004-07-09_18h11m16s.txt
# input/detection-results/D2004-07-09_18h17m15s.jpg.txt
# D2004-07-09_18h17m15s.txt
# input/detection-results/D2004-07-09_19h08m37s.jpg.txt
# D2004-07-09_19h08m37s.txt
# input/detection-results/D2004-07-09_20h02m53s.jpg.txt
# D2004-07-09_20h02m53s.txt
# input/detection-results/D2004-07-09_21h27m05s.jpg.txt
# D2004-07-09_21h27m05s.txt
# input/detection-results/D2004-07-09_21h52m21s.jpg.txt
# D2004-07-09_21h52m21s.txt
# input/detection-results/D2004-07-09_22h25m11s.jpg.txt
# D2004-07-09_22h25m11s.txt
# input/detection-results/D2004-07-09_22h30m55s.jpg.txt
# D2004-07-09_22h30m55s.txt
# input/detection-results/D2004-07-10_02h54m18s.jpg.txt
# D2004-07-10_02h54m18s.txt
# input/detection-results/D2004-07-18_13h21m58s.jpg.txt
# D2004-07-18_13h21m58s.txt
# input/detection-results/D2004-07-18_15h56m59s.jpg.txt
# D2004-07-18_15h56m59s.txt
# input/detection-results/D2004-07-25_11h25m12s.jpg.txt
# D2004-07-25_11h25m12s.txt
# input/detection-results/D2004-07-25_12h26m41s.jpg.txt
# D2004-07-25_12h26m41s.txt
# input/detection-results/D2004-08-07_14h38m48s.jpg.txt
# D2004-08-07_14h38m48s.txt
# input/detection-results/D2004-08-16_10h13m11s.jpg.txt
# D2004-08-16_10h13m11s.txt
# input/detection-results/D2004-08-16_14h33m40s.jpg.txt
# D2004-08-16_14h33m40s.txt
# input/detection-results/D2004-08-16_17h46m53s.jpg.txt
# D2004-08-16_17h46m53s.txt
# input/detection-results/D2004-08-16_18h14m05s.jpg.txt
# D2004-08-16_18h14m05s.txt
# input/detection-results/D2004-08-17_09h50m11s.jpg.txt
# D2004-08-17_09h50m11s.txt
# input/detection-results/D2004-08-17_11h27m30s.jpg.txt
# D2004-08-17_11h27m30s.txt
# input/detection-results/D2004-08-17_13h34m32s.jpg.txt
# D2004-08-17_13h34m32s.txt
# input/detection-results/D2004-08-17_14h29m45s.jpg.txt
# D2004-08-17_14h29m45s.txt
# input/detection-results/D2004-08-17_16h17m58s.jpg.txt
# D2004-08-17_16h17m58s.txt
# input/detection-results/D2004-08-18_10h43m07s.jpg.txt
# D2004-08-18_10h43m07s.txt
# input/detection-results/D2004-08-18_16h06m52s.jpg.txt
# D2004-08-18_16h06m52s.txt
# input/detection-results/D2004-08-18_17h59m51s.jpg.txt
# D2004-08-18_17h59m51s.txt
# input/detection-results/D2004-08-18_18h54m20s.jpg.txt
# D2004-08-18_18h54m20s.txt
# input/detection-results/D2004-08-19_12h59m58s.jpg.txt
# D2004-08-19_12h59m58s.txt
# input/detection-results/D2004-08-19_13h22m04s.jpg.txt
# D2004-08-19_13h22m04s.txt
# input/detection-results/D2004-08-19_13h22m54s.jpg.txt
# D2004-08-19_13h22m54s.txt
# input/detection-results/D2004-08-19_13h30m48s.jpg.txt
# D2004-08-19_13h30m48s.txt
# input/detection-results/D2004-08-19_15h28m28s.jpg.txt
# D2004-08-19_15h28m28s.txt
# input/detection-results/D2004-08-19_16h29m34s.jpg.txt
# D2004-08-19_16h29m34s.txt
# input/detection-results/D2004-08-19_18h18m18s.jpg.txt
# D2004-08-19_18h18m18s.txt
# input/detection-results/D2004-08-20_11h04m42s.jpg.txt
# D2004-08-20_11h04m42s.txt
# input/detection-results/D2004-08-20_11h41m04s.jpg.txt
# D2004-08-20_11h41m04s.txt
# input/detection-results/D2004-08-20_12h05m11s.jpg.txt
# D2004-08-20_12h05m11s.txt
# input/detection-results/D2004-08-20_12h37m02s.jpg.txt
# D2004-08-20_12h37m02s.txt
# input/detection-results/D2004-08-21_10h06m43s.jpg.txt
# D2004-08-21_10h06m43s.txt
# input/detection-results/D2004-08-21_10h49m39s.jpg.txt
# D2004-08-21_10h49m39s.txt
# input/detection-results/D2004-08-21_10h59m45s.jpg.txt
# D2004-08-21_10h59m45s.txt
# input/detection-results/D2004-08-21_14h09m14s.jpg.txt
# D2004-08-21_14h09m14s.txt
# input/detection-results/D2004-08-21_16h59m25s.jpg.txt
# D2004-08-21_16h59m25s.txt
# input/detection-results/D2004-08-22_09h43m19s.jpg.txt
# D2004-08-22_09h43m19s.txt
# input/detection-results/D2004-08-22_09h49m40s.jpg.txt
# D2004-08-22_09h49m40s.txt
# input/detection-results/D2004-08-22_12h05m47s.jpg.txt
# D2004-08-22_12h05m47s.txt
# input/detection-results/D2004-08-22_12h10m27s.jpg.txt
# D2004-08-22_12h10m27s.txt
# input/detection-results/D2004-08-22_12h18m46s.jpg.txt
# D2004-08-22_12h18m46s.txt
# input/detection-results/D2004-08-22_12h24m05s.jpg.txt
# D2004-08-22_12h24m05s.txt
# input/detection-results/D2004-08-22_14h41m59s.jpg.txt
# D2004-08-22_14h41m59s.txt
# input/detection-results/D2004-08-22_17h02m31s.jpg.txt
# D2004-08-22_17h02m31s.txt
# input/detection-results/D2004-08-22_18h12m03s.jpg.txt
# D2004-08-22_18h12m03s.txt
# input/detection-results/D2004-08-22_19h18m30s.jpg.txt
# D2004-08-22_19h18m30s.txt
# input/detection-results/D2004-08-23_12h31m12s.jpg.txt
# D2004-08-23_12h31m12s.txt
# input/detection-results/D2004-08-23_12h33m21s.jpg.txt
# D2004-08-23_12h33m21s.txt
# input/detection-results/D2004-08-23_12h38m23s.jpg.txt
# D2004-08-23_12h38m23s.txt
# input/detection-results/D2004-08-23_12h42m36s.jpg.txt
# D2004-08-23_12h42m36s.txt
# input/detection-results/D2004-08-23_15h35m56s.jpg.txt
# D2004-08-23_15h35m56s.txt
# input/detection-results/D2004-08-24_12h44m04s.jpg.txt
# D2004-08-24_12h44m04s.txt
# input/detection-results/D2004-08-24_14h17m59s.jpg.txt
# D2004-08-24_14h17m59s.txt
# input/detection-results/D2004-08-24_16h28m39s.jpg.txt
# D2004-08-24_16h28m39s.txt
# input/detection-results/D2004-08-24_17h11m07s.jpg.txt
# D2004-08-24_17h11m07s.txt
# input/detection-results/D2004-08-24_19h56m52s.jpg.txt
# D2004-08-24_19h56m52s.txt
# input/detection-results/D2004-08-24_21h00m12s.jpg.txt
# D2004-08-24_21h00m12s.txt
# input/detection-results/D2004-08-24_21h44m09s.jpg.txt
# D2004-08-24_21h44m09s.txt
# input/detection-results/D2004-08-25_14h16m32s.jpg.txt
# D2004-08-25_14h16m32s.txt
# input/detection-results/D2004-08-25_14h24m19s.jpg.txt
# D2004-08-25_14h24m19s.txt
# input/detection-results/D2004-08-25_18h20m04s.jpg.txt
# D2004-08-25_18h20m04s.txt
# input/detection-results/D2004-09-04_15h14m39s.jpg.txt
# D2004-09-04_15h14m39s.txt
# input/detection-results/D2004-09-13_14h38m33s.jpg.txt
# D2004-09-13_14h38m33s.txt
# input/detection-results/D2004-09-18_15h09m49s.jpg.txt
# D2004-09-18_15h09m49s.txt
# input/detection-results/D2004-09-18_15h28m13s.jpg.txt
# D2004-09-18_15h28m13s.txt
# input/detection-results/D2004-09-18_15h57m02s.jpg.txt
# D2004-09-18_15h57m02s.txt
# input/detection-results/D2004-09-18_16h16m49s.jpg.txt
# D2004-09-18_16h16m49s.txt
# input/detection-results/D2004-09-18_16h58m08s.jpg.txt
# D2004-09-18_16h58m08s.txt
# input/detection-results/D2004-09-18_17h24m23s.jpg.txt
# D2004-09-18_17h24m23s.txt
# input/detection-results/D2004-09-19_10h19m52s.jpg.txt
# D2004-09-19_10h19m52s.txt
# input/detection-results/D2004-09-19_11h58m56s.jpg.txt
# D2004-09-19_11h58m56s.txt
# input/detection-results/D2004-09-19_14h57m48s.jpg.txt
# D2004-09-19_14h57m48s.txt
# input/detection-results/D2004-09-19_16h05m31s.jpg.txt
# D2004-09-19_16h05m31s.txt
# input/detection-results/D2004-09-24_14h37m43s.jpg.txt
# D2004-09-24_14h37m43s.txt
# input/detection-results/D2004-09-24_14h42m22s.jpg.txt
# D2004-09-24_14h42m22s.txt
# input/detection-results/D2004-09-24_14h48m16s.jpg.txt
# D2004-09-24_14h48m16s.txt
# input/detection-results/D2004-10-02_10h26m23s.jpg.txt
# D2004-10-02_10h26m23s.txt
# input/detection-results/D2004-10-02_10h52m13s.jpg.txt
# D2004-10-02_10h52m13s.txt
# input/detection-results/D2004-11-07_18h37m53s.jpg.txt
# D2004-11-07_18h37m53s.txt
# input/detection-results/D2004-11-07_19h02m42s.jpg.txt
# D2004-11-07_19h02m42s.txt
# input/detection-results/D2004-11-09_10h30m38s.jpg.txt
# D2004-11-09_10h30m38s.txt
# input/detection-results/D2004-11-09_10h43m56s.jpg.txt
# D2004-11-09_10h43m56s.txt
# input/detection-results/D2004-11-09_11h24m12s.jpg.txt
# D2004-11-09_11h24m12s.txt
# input/detection-results/D2004-11-17_14h54m39s.jpg.txt
# D2004-11-17_14h54m39s.txt
# input/detection-results/D2004-11-18_01h51m47s.jpg.txt
# D2004-11-18_01h51m47s.txt
# input/detection-results/D2004-11-18_13h35m07s.jpg.txt
# D2004-11-18_13h35m07s.txt
# input/detection-results/D2004-11-18_18h11m57s.jpg.txt
# D2004-11-18_18h11m57s.txt
# input/detection-results/dsc00009.jpg.txt
# dsc00009.txt
# input/detection-results/dsc00179.jpg.txt
# dsc00179.txt
# input/detection-results/dsc00182.jpg.txt
# dsc00182.txt
# input/detection-results/dsc00197.jpg.txt
# dsc00197.txt
# input/detection-results/dsc00208.jpg.txt
# dsc00208.txt
# input/detection-results/dsc00232.jpg.txt
# dsc00232.txt
# input/detection-results/no_person__no_bike_003.png.txt
# no_person__no_bike_003.txt
# input/detection-results/no_person__no_bike_006.png.txt
# no_person__no_bike_006.txt
# input/detection-results/no_person__no_bike_009.png.txt
# no_person__no_bike_009.txt
# input/detection-results/no_person__no_bike_012.png.txt
# no_person__no_bike_012.txt
# input/detection-results/no_person__no_bike_015.png.txt
# no_person__no_bike_015.txt
# input/detection-results/no_person__no_bike_018.png.txt
# no_person__no_bike_018.txt
# input/detection-results/no_person__no_bike_021.png.txt
# no_person__no_bike_021.txt
# input/detection-results/no_person__no_bike_024.png.txt
# no_person__no_bike_024.txt
# input/detection-results/no_person__no_bike_027.png.txt
# no_person__no_bike_027.txt
# input/detection-results/no_person__no_bike_030.png.txt
# no_person__no_bike_030.txt
# input/detection-results/no_person__no_bike_033.png.txt
# no_person__no_bike_033.txt
# input/detection-results/no_person__no_bike_036.png.txt
# no_person__no_bike_036.txt
# input/detection-results/no_person__no_bike_039.png.txt
# no_person__no_bike_039.txt
# input/detection-results/no_person__no_bike_042.png.txt
# no_person__no_bike_042.txt
# input/detection-results/no_person__no_bike_045.png.txt
# no_person__no_bike_045.txt
# input/detection-results/no_person__no_bike_048.png.txt
# no_person__no_bike_048.txt
# input/detection-results/no_person__no_bike_051.png.txt
# no_person__no_bike_051.txt
# input/detection-results/no_person__no_bike_054.png.txt
# no_person__no_bike_054.txt
# input/detection-results/no_person__no_bike_057.png.txt
# no_person__no_bike_057.txt
# input/detection-results/no_person__no_bike_060.png.txt
# no_person__no_bike_060.txt
# input/detection-results/no_person__no_bike_063.png.txt
# no_person__no_bike_063.txt
# input/detection-results/no_person__no_bike_066.png.txt
# no_person__no_bike_066.txt
# input/detection-results/no_person__no_bike_069.png.txt
# no_person__no_bike_069.txt
# input/detection-results/no_person__no_bike_072.png.txt
# no_person__no_bike_072.txt
# input/detection-results/no_person__no_bike_075.png.txt
# no_person__no_bike_075.txt
# input/detection-results/no_person__no_bike_078.png.txt
# no_person__no_bike_078.txt
# input/detection-results/no_person__no_bike_081.png.txt
# no_person__no_bike_081.txt
# input/detection-results/no_person__no_bike_084.png.txt
# no_person__no_bike_084.txt
# input/detection-results/no_person__no_bike_087.png.txt
# no_person__no_bike_087.txt
# input/detection-results/no_person__no_bike_090.png.txt
# no_person__no_bike_090.txt
# input/detection-results/no_person__no_bike_093.png.txt
# no_person__no_bike_093.txt
# input/detection-results/no_person__no_bike_096.png.txt
# no_person__no_bike_096.txt
# input/detection-results/no_person__no_bike_099.png.txt
# no_person__no_bike_099.txt
# input/detection-results/no_person__no_bike_102.png.txt
# no_person__no_bike_102.txt
# input/detection-results/no_person__no_bike_105.png.txt
# no_person__no_bike_105.txt
# input/detection-results/no_person__no_bike_108.png.txt
# no_person__no_bike_108.txt
# input/detection-results/no_person__no_bike_111.png.txt
# no_person__no_bike_111.txt
# input/detection-results/no_person__no_bike_114.png.txt
# no_person__no_bike_114.txt
# input/detection-results/no_person__no_bike_117.png.txt
# no_person__no_bike_117.txt
# input/detection-results/no_person__no_bike_120.png.txt
# no_person__no_bike_120.txt
# input/detection-results/no_person__no_bike_123.png.txt
# no_person__no_bike_123.txt
# input/detection-results/no_person__no_bike_126.png.txt
# no_person__no_bike_126.txt
# input/detection-results/no_person__no_bike_129.png.txt
# no_person__no_bike_129.txt
# input/detection-results/no_person__no_bike_132.png.txt
# no_person__no_bike_132.txt
# input/detection-results/no_person__no_bike_135.png.txt
# no_person__no_bike_135.txt
# input/detection-results/no_person__no_bike_138.png.txt
# no_person__no_bike_138.txt
# input/detection-results/no_person__no_bike_141.png.txt
# no_person__no_bike_141.txt
# input/detection-results/no_person__no_bike_144.png.txt
# no_person__no_bike_144.txt
# input/detection-results/no_person__no_bike_148.png.txt
# no_person__no_bike_148.txt
# input/detection-results/no_person__no_bike_151.png.txt
# no_person__no_bike_151.txt
# input/detection-results/no_person__no_bike_154.png.txt
# no_person__no_bike_154.txt
# input/detection-results/no_person__no_bike_157.png.txt
# no_person__no_bike_157.txt
# input/detection-results/no_person__no_bike_160.png.txt
# no_person__no_bike_160.txt
# input/detection-results/no_person__no_bike_163.png.txt
# no_person__no_bike_163.txt
# input/detection-results/no_person__no_bike_167.png.txt
# no_person__no_bike_167.txt
# input/detection-results/no_person__no_bike_170.png.txt
# no_person__no_bike_170.txt
# input/detection-results/no_person__no_bike_173.png.txt
# no_person__no_bike_173.txt
# input/detection-results/no_person__no_bike_176.png.txt
# no_person__no_bike_176.txt
# input/detection-results/no_person__no_bike_179.png.txt
# no_person__no_bike_179.txt
# input/detection-results/no_person__no_bike_182.png.txt
# no_person__no_bike_182.txt
# input/detection-results/no_person__no_bike_185.png.txt
# no_person__no_bike_185.txt
# input/detection-results/no_person__no_bike_188.png.txt
# no_person__no_bike_188.txt
# input/detection-results/no_person__no_bike_191.png.txt
# no_person__no_bike_191.txt
# input/detection-results/no_person__no_bike_194.png.txt
# no_person__no_bike_194.txt
# input/detection-results/no_person__no_bike_197.png.txt
# no_person__no_bike_197.txt
# input/detection-results/no_person__no_bike_200.png.txt
# no_person__no_bike_200.txt
# input/detection-results/no_person__no_bike_203.png.txt
# no_person__no_bike_203.txt
# input/detection-results/no_person__no_bike_206.png.txt
# no_person__no_bike_206.txt
# input/detection-results/no_person__no_bike_209.png.txt
# no_person__no_bike_209.txt
# input/detection-results/no_person__no_bike_212.png.txt
# no_person__no_bike_212.txt
# input/detection-results/no_person__no_bike_215.png.txt
# no_person__no_bike_215.txt
# input/detection-results/no_person__no_bike_218.png.txt
# no_person__no_bike_218.txt
# input/detection-results/no_person__no_bike_221.png.txt
# no_person__no_bike_221.txt
# input/detection-results/no_person__no_bike_224.png.txt
# no_person__no_bike_224.txt
# input/detection-results/no_person__no_bike_227.png.txt
# no_person__no_bike_227.txt
# input/detection-results/no_person__no_bike_230.png.txt
# no_person__no_bike_230.txt
# input/detection-results/no_person__no_bike_233.png.txt
# no_person__no_bike_233.txt
# input/detection-results/no_person__no_bike_236.png.txt
# no_person__no_bike_236.txt
# input/detection-results/no_person__no_bike_239.png.txt
# no_person__no_bike_239.txt
# input/detection-results/no_person__no_bike_242.png.txt
# no_person__no_bike_242.txt
# input/detection-results/no_person__no_bike_245.png.txt
# no_person__no_bike_245.txt
# input/detection-results/no_person__no_bike_248.png.txt
# no_person__no_bike_248.txt
# input/detection-results/no_person__no_bike_251.png.txt
# no_person__no_bike_251.txt
# input/detection-results/no_person__no_bike_254.png.txt
# no_person__no_bike_254.txt
# input/detection-results/no_person__no_bike_257.png.txt
# no_person__no_bike_257.txt
# input/detection-results/no_person__no_bike_260.png.txt
# no_person__no_bike_260.txt
# input/detection-results/no_person__no_bike_263.png.txt
# no_person__no_bike_263.txt
# input/detection-results/no_person__no_bike_266.png.txt
# no_person__no_bike_266.txt
# input/detection-results/no_person__no_bike_270.png.txt
# no_person__no_bike_270.txt
# input/detection-results/no_person__no_bike_273.png.txt
# no_person__no_bike_273.txt
# input/detection-results/person_007.png.txt
# person_007.txt
# input/detection-results/person_008.png.txt
# person_008.txt
# input/detection-results/person_009.png.txt
# person_009.txt
# input/detection-results/person_010.png.txt
# person_010.txt
# input/detection-results/person_011.png.txt
# person_011.txt
# input/detection-results/person_012.png.txt
# person_012.txt
# input/detection-results/person_013.png.txt
# person_013.txt
# input/detection-results/person_014.png.txt
# person_014.txt
# input/detection-results/person_015.png.txt
# person_015.txt
# input/detection-results/person_026.png.txt
# person_026.txt
# input/detection-results/person_028.png.txt
# person_028.txt
# input/detection-results/person_029.png.txt
# person_029.txt
# input/detection-results/person_030.png.txt
# person_030.txt
# input/detection-results/person_032.png.txt
# person_032.txt
# input/detection-results/person_033.png.txt
# person_033.txt
# input/detection-results/person_034.png.txt
# person_034.txt
# input/detection-results/person_036.png.txt
# person_036.txt
# input/detection-results/person_037.png.txt
# person_037.txt
# input/detection-results/person_038.png.txt
# person_038.txt
# input/detection-results/person_039.png.txt
# person_039.txt
# input/detection-results/person_040.png.txt
# person_040.txt
# input/detection-results/person_051.png.txt
# person_051.txt
# input/detection-results/person_052.png.txt
# person_052.txt
# input/detection-results/person_053.png.txt
# person_053.txt
# input/detection-results/person_055.png.txt
# person_055.txt
# input/detection-results/person_056.png.txt
# person_056.txt
# input/detection-results/person_058.png.txt
# person_058.txt
# input/detection-results/person_059.png.txt
# person_059.txt
# input/detection-results/person_062.png.txt
# person_062.txt
# input/detection-results/person_063.png.txt
# person_063.txt
# input/detection-results/person_064.png.txt
# person_064.txt
# input/detection-results/person_065.png.txt
# person_065.txt
# input/detection-results/person_070.png.txt
# person_070.txt
# input/detection-results/person_071.png.txt
# person_071.txt
# input/detection-results/person_073.png.txt
# person_073.txt
# input/detection-results/person_075.png.txt
# person_075.txt
# input/detection-results/person_076.png.txt
# person_076.txt
# input/detection-results/person_085.png.txt
# person_085.txt
# input/detection-results/person_087.png.txt
# person_087.txt
# input/detection-results/person_088.png.txt
# person_088.txt
# input/detection-results/person_089.png.txt
# person_089.txt
# input/detection-results/person_090.png.txt
# person_090.txt
# input/detection-results/person_092.png.txt
# person_092.txt
# input/detection-results/person_093.png.txt
# person_093.txt
# input/detection-results/person_094.png.txt
# person_094.txt
# input/detection-results/person_095.png.txt
# person_095.txt
# input/detection-results/person_096.png.txt
# person_096.txt
# input/detection-results/person_098.png.txt
# person_098.txt
# input/detection-results/person_099.png.txt
# person_099.txt
# input/detection-results/person_100.png.txt
# person_100.txt
# input/detection-results/person_104.png.txt
# person_104.txt
# input/detection-results/person_105.png.txt
# person_105.txt
# input/detection-results/person_107.png.txt
# person_107.txt
# input/detection-results/person_115.png.txt
# person_115.txt
# input/detection-results/person_118.png.txt
# person_118.txt
# input/detection-results/person_120.png.txt
# person_120.txt
# input/detection-results/person_122.png.txt
# person_122.txt
# input/detection-results/person_127.png.txt
# person_127.txt
# input/detection-results/person_132.png.txt
# person_132.txt
# input/detection-results/person_134.png.txt
# person_134.txt
# input/detection-results/person_135.png.txt
# person_135.txt
# input/detection-results/person_136.png.txt
# person_136.txt
# input/detection-results/person_137.png.txt
# person_137.txt
# input/detection-results/person_138.png.txt
# person_138.txt
# input/detection-results/person_159.png.txt
# person_159.txt
# input/detection-results/person_161.png.txt
# person_161.txt
# input/detection-results/person_164.png.txt
# person_164.txt
# input/detection-results/person_186.png.txt
# person_186.txt
# input/detection-results/person_188.png.txt
# person_188.txt
# input/detection-results/person_189.png.txt
# person_189.txt
# input/detection-results/person_190.png.txt
# person_190.txt
# input/detection-results/person_191.png.txt
# person_191.txt
# input/detection-results/person_193.png.txt
# person_193.txt
# input/detection-results/person_194.png.txt
# person_194.txt
# input/detection-results/person_198.png.txt
# person_198.txt
# input/detection-results/person_200.png.txt
# person_200.txt
# input/detection-results/person_204.png.txt
# person_204.txt
# input/detection-results/person_206.png.txt
# person_206.txt
# input/detection-results/person_207.png.txt
# person_207.txt
# input/detection-results/person_210.png.txt
# person_210.txt
# input/detection-results/person_212.png.txt
# person_212.txt
# input/detection-results/person_216.png.txt
# person_216.txt
# input/detection-results/person_217.png.txt
# person_217.txt
# input/detection-results/person_218.png.txt
# person_218.txt
# input/detection-results/person_222.png.txt
# person_222.txt
# input/detection-results/person_230.png.txt
# person_230.txt
# input/detection-results/person_236.png.txt
# person_236.txt
# input/detection-results/person_246.png.txt
# person_246.txt
# input/detection-results/person_247.png.txt
# person_247.txt
# input/detection-results/person_248.png.txt
# person_248.txt
# input/detection-results/person_249.png.txt
# person_249.txt
# input/detection-results/person_250.png.txt
# person_250.txt
# input/detection-results/person_251.png.txt
# person_251.txt
# input/detection-results/person_255.png.txt
# person_255.txt
# input/detection-results/person_263.png.txt
# person_263.txt
# input/detection-results/person_265.png.txt
# person_265.txt
# input/detection-results/person_272.png.txt
# person_272.txt
# input/detection-results/person_280.png.txt
# person_280.txt
# input/detection-results/person_282.png.txt
# person_282.txt
# input/detection-results/person_290.png.txt
# person_290.txt
# input/detection-results/person_293.png.txt
# person_293.txt
# input/detection-results/person_303.png.txt
# person_303.txt
# input/detection-results/person_306.png.txt
# person_306.txt
# input/detection-results/person_314.png.txt
# person_314.txt
# input/detection-results/person_315.png.txt
# person_315.txt
# input/detection-results/person_316.png.txt
# person_316.txt
# input/detection-results/person_317.png.txt
# person_317.txt
# input/detection-results/person_318.png.txt
# person_318.txt
# input/detection-results/person_323.png.txt
# person_323.txt
# input/detection-results/person_325.png.txt
# person_325.txt
# input/detection-results/person_335.png.txt
# person_335.txt
# input/detection-results/person_336.png.txt
# person_336.txt
# input/detection-results/person_337.png.txt
# person_337.txt
# input/detection-results/person_347.png.txt
# person_347.txt
# input/detection-results/person_350.png.txt
# person_350.txt
# input/detection-results/person_and_bike_004.png.txt
# person_and_bike_004.txt
# input/detection-results/person_and_bike_006.png.txt
# person_and_bike_006.txt
# input/detection-results/person_and_bike_012.png.txt
# person_and_bike_012.txt
# input/detection-results/person_and_bike_014.png.txt
# person_and_bike_014.txt
# input/detection-results/person_and_bike_027.png.txt
# person_and_bike_027.txt
# input/detection-results/person_and_bike_028.png.txt
# person_and_bike_028.txt
# input/detection-results/person_and_bike_029.png.txt
# person_and_bike_029.txt
# input/detection-results/person_and_bike_035.png.txt
# person_and_bike_035.txt
# input/detection-results/person_and_bike_038.png.txt
# person_and_bike_038.txt
# input/detection-results/person_and_bike_042.png.txt
# person_and_bike_042.txt
# input/detection-results/person_and_bike_043.png.txt
# person_and_bike_043.txt
# input/detection-results/person_and_bike_044.png.txt
# person_and_bike_044.txt
# input/detection-results/person_and_bike_045.png.txt
# person_and_bike_045.txt
# input/detection-results/person_and_bike_046.png.txt
# person_and_bike_046.txt
# input/detection-results/person_and_bike_047.png.txt
# person_and_bike_047.txt
# input/detection-results/person_and_bike_048.png.txt
# person_and_bike_048.txt
# input/detection-results/person_and_bike_049.png.txt
# person_and_bike_049.txt
# input/detection-results/person_and_bike_050.png.txt
# person_and_bike_050.txt
# input/detection-results/person_and_bike_051.png.txt
# person_and_bike_051.txt
# input/detection-results/person_and_bike_052.png.txt
# person_and_bike_052.txt
# input/detection-results/person_and_bike_053.png.txt
# person_and_bike_053.txt
# input/detection-results/person_and_bike_054.png.txt
# person_and_bike_054.txt
# input/detection-results/person_and_bike_055.png.txt
# person_and_bike_055.txt
# input/detection-results/person_and_bike_056.png.txt
# person_and_bike_056.txt
# input/detection-results/person_and_bike_057.png.txt
# person_and_bike_057.txt
# input/detection-results/person_and_bike_058.png.txt
# person_and_bike_058.txt
# input/detection-results/person_and_bike_059.png.txt
# person_and_bike_059.txt
# input/detection-results/person_and_bike_060.png.txt
# person_and_bike_060.txt
# input/detection-results/person_and_bike_061.png.txt
# person_and_bike_061.txt
# input/detection-results/person_and_bike_062.png.txt
# person_and_bike_062.txt
# input/detection-results/person_and_bike_063.png.txt
# person_and_bike_063.txt
# input/detection-results/person_and_bike_064.png.txt
# person_and_bike_064.txt
# input/detection-results/person_and_bike_065.png.txt
# person_and_bike_065.txt
# input/detection-results/person_and_bike_066.png.txt
# person_and_bike_066.txt
# input/detection-results/person_and_bike_067.png.txt
# person_and_bike_067.txt
# input/detection-results/person_and_bike_069.png.txt
# person_and_bike_069.txt
# input/detection-results/person_and_bike_070.png.txt
# person_and_bike_070.txt
# input/detection-results/person_and_bike_071.png.txt
# person_and_bike_071.txt
# input/detection-results/person_and_bike_072.png.txt
# person_and_bike_072.txt
# input/detection-results/person_and_bike_073.png.txt
# person_and_bike_073.txt
# input/detection-results/person_and_bike_076.png.txt
# person_and_bike_076.txt
# input/detection-results/person_and_bike_077.png.txt
# person_and_bike_077.txt
# input/detection-results/person_and_bike_079.png.txt
# person_and_bike_079.txt
# input/detection-results/person_and_bike_080.png.txt
# person_and_bike_080.txt
# input/detection-results/person_and_bike_081.png.txt
# person_and_bike_081.txt
# input/detection-results/person_and_bike_082.png.txt
# person_and_bike_082.txt
# input/detection-results/person_and_bike_083.png.txt
# person_and_bike_083.txt
# input/detection-results/person_and_bike_084.png.txt
# person_and_bike_084.txt
# input/detection-results/person_and_bike_085.png.txt
# person_and_bike_085.txt
# input/detection-results/person_and_bike_086.png.txt
# person_and_bike_086.txt
# input/detection-results/person_and_bike_087.png.txt
# person_and_bike_087.txt
# input/detection-results/person_and_bike_088.png.txt
# person_and_bike_088.txt
# input/detection-results/person_and_bike_089.png.txt
# person_and_bike_089.txt
# input/detection-results/person_and_bike_090.png.txt
# person_and_bike_090.txt
# input/detection-results/person_and_bike_091.png.txt
# person_and_bike_091.txt
# input/detection-results/person_and_bike_092.png.txt
# person_and_bike_092.txt
# input/detection-results/person_and_bike_093.png.txt
# person_and_bike_093.txt
# input/detection-results/person_and_bike_094.png.txt
# person_and_bike_094.txt
# input/detection-results/person_and_bike_095.png.txt
# person_and_bike_095.txt
# input/detection-results/person_and_bike_096.png.txt
# person_and_bike_096.txt
# input/detection-results/person_and_bike_097.png.txt
# person_and_bike_097.txt
# input/detection-results/person_and_bike_098.png.txt
# person_and_bike_098.txt
# input/detection-results/person_and_bike_099.png.txt
# person_and_bike_099.txt
# input/detection-results/person_and_bike_100.png.txt
# person_and_bike_100.txt
# input/detection-results/person_and_bike_101.png.txt
# person_and_bike_101.txt
# input/detection-results/person_and_bike_102.png.txt
# person_and_bike_102.txt
# input/detection-results/person_and_bike_103.png.txt
# person_and_bike_103.txt
# input/detection-results/person_and_bike_104.png.txt
# person_and_bike_104.txt
# input/detection-results/person_and_bike_105.png.txt
# person_and_bike_105.txt
# input/detection-results/person_and_bike_106.png.txt
# person_and_bike_106.txt
# input/detection-results/person_and_bike_107.png.txt
# person_and_bike_107.txt
# input/detection-results/person_and_bike_108.png.txt
# person_and_bike_108.txt
# input/detection-results/person_and_bike_109.png.txt
# person_and_bike_109.txt
# input/detection-results/person_and_bike_110.png.txt
# person_and_bike_110.txt
# input/detection-results/person_and_bike_111.png.txt
# person_and_bike_111.txt
# input/detection-results/person_and_bike_112.png.txt
# person_and_bike_112.txt
# input/detection-results/person_and_bike_113.png.txt
# person_and_bike_113.txt
# input/detection-results/person_and_bike_114.png.txt
# person_and_bike_114.txt
# input/detection-results/person_and_bike_126.png.txt
# person_and_bike_126.txt
# input/detection-results/person_and_bike_133.png.txt
# person_and_bike_133.txt
# input/detection-results/person_and_bike_136.png.txt
# person_and_bike_136.txt
# input/detection-results/person_and_bike_140.png.txt
# person_and_bike_140.txt
# input/detection-results/person_and_bike_141.png.txt
# person_and_bike_141.txt
# input/detection-results/person_and_bike_149.png.txt
# person_and_bike_149.txt
# input/detection-results/person_and_bike_153.png.txt
# person_and_bike_153.txt
# input/detection-results/person_and_bike_159.png.txt
# person_and_bike_159.txt
# input/detection-results/person_and_bike_160.png.txt
# person_and_bike_160.txt
# input/detection-results/person_and_bike_161.png.txt
# person_and_bike_161.txt
# input/detection-results/person_and_bike_162.png.txt
# person_and_bike_162.txt
# input/detection-results/person_and_bike_163.png.txt
# person_and_bike_163.txt
# input/detection-results/person_and_bike_164.png.txt
# person_and_bike_164.txt
# input/detection-results/person_and_bike_165.png.txt
# person_and_bike_165.txt
# input/detection-results/person_and_bike_177.png.txt
# person_and_bike_177.txt
# input/detection-results/person_and_bike_181.png.txt
# person_and_bike_181.txt
# input/detection-results/person_and_bike_188.png.txt
# person_and_bike_188.txt
# input/detection-results/person_and_bike_189.png.txt
# person_and_bike_189.txt
# input/detection-results/person_and_bike_190.png.txt
# person_and_bike_190.txt
# input/detection-results/prefecture.jpg.txt
# prefecture.txt

# %%
# 若是用xml格式, 可用get_gt_txt.py生成檔案
# 沒有的話就自己手動轉格式
# 從test.txt(有標註資料)生成ground-truth資料
if not os.path.exists("./input"):
    os.makedirs("./input")
if not os.path.exists("./input/ground-truth"):
    os.makedirs("./input/ground-truth")
    
    
import re
pattern = r'(\/\w+\/\w+\/)(.*\.\w+)'
f = open('test.txt')
# ff = open(path, 'w')
for line in f.readlines():
    fname = re.search(pattern, line, flags=0).group(2)[:-4]
    annotations = line.split()[1:]
    if annotations != []: # 若有標註資料
        for annotation in annotations:
            content = ''
            annotation = annotation.split(',')
            content = 'person' + ' ' + annotation[0] + ' ' + annotation[1] + ' ' + annotation [2] + ' ' + annotation[3]
            print(content)
            with open("./input/ground-truth/"+fname+".txt", "w") as new_f:
                new_f.write(content+'\n')
    else:
        with open("./input/ground-truth/"+fname+".txt", "w") as new_f:
                new_f.write('')
    print('...............................')
f.close()
# Out:
# person 142 66 340 646
# ...............................
# person 110 80 214 469
# ...............................
# person 316 37 434 440
# ...............................
# person 141 53 239 347
# ...............................
# person 171 72 260 321
# person 35 60 155 320
# ...............................
# person 145 91 390 626
# ...............................
# person 530 113 742 581
# ...............................
# person 475 68 621 709
# ...............................
# person 303 68 478 655
# ...............................
# person 151 143 373 626
# ...............................
# person 194 118 363 626
# ...............................
# person 190 104 479 647
# ...............................
# person 581 83 755 662
# ...............................
# person 513 63 684 718
# ...............................
# person 254 64 460 602
# ...............................
# person 413 82 624 667
# ...............................
# person 261 71 386 505
# ...............................
# person 289 49 469 533
# ...............................
# person 467 80 648 565
# ...............................
# person 184 111 346 616
# ...............................
# person 294 75 530 663
# ...............................
# person 135 274 239 500
# person 332 151 467 446
# person 512 168 610 507
# person 709 93 836 531
# ...............................
# person 429 40 636 666
# person 65 41 219 602
# ...............................
# person 155 65 224 306
# person 288 44 374 286
# person 79 56 156 307
# ...............................
# person 250 151 299 294
# person 215 354 274 466
# person 568 320 607 433
# person 829 180 881 321
# ...............................
# person 258 281 324 457
# person 339 281 400 459
# ...............................
# person 304 261 455 761
# ...............................
# person 519 276 676 676
# person 310 261 450 597
# person 853 277 994 769
# ...............................
# person 367 246 467 629
# person 291 234 381 479
# person 533 258 663 645
# ...............................
# person 486 222 653 765
# person 292 251 425 729
# ...............................
# person 194 176 256 418
# person 262 182 314 375
# person 372 181 433 368
# person 419 159 475 344
# person 492 170 558 382
# person 550 181 605 384
# ...............................
# person 559 217 730 795
# person 928 175 975 373
# person 978 181 1020 338
# ...............................
# person 233 220 354 536
# person 24 233 95 420
# ...............................
# person 755 325 847 645
# person 638 340 707 538
# person 405 343 474 538
# person 213 342 285 554
# person 964 339 1015 500
# ...............................
# person 385 262 535 776
# person 229 221 381 793
# ...............................
# person 425 225 555 701
# ...............................
# person 546 202 630 647
# person 414 213 547 657
# ...............................
# person 533 248 628 582
# ...............................
# person 305 350 370 565
# person 155 173 227 384
# person 451 355 535 579
# person 747 357 814 533
# person 527 62 576 193
# ...............................
# person 105 131 226 434
# person 233 292 302 438
# ...............................
# person 238 277 306 562
# person 321 292 407 561
# person 589 259 672 560
# person 791 271 901 562
# person 510 267 587 538
# ...............................
# person 203 212 296 487
# ...............................
# person 708 142 950 906
# ...............................
# person 326 241 378 427
# person 406 218 457 431
# person 488 223 556 446
# person 246 241 303 423
# person 624 229 690 437
# ...............................
# person 294 334 450 878
# ...............................
# person 317 205 412 527
# ...............................
# person 302 163 394 501
# person 200 150 281 507
# person 414 148 471 395
# person 501 123 573 397
# person 570 146 619 386
# person 632 131 690 393
# person 695 145 747 399
# person 746 142 797 402
# person 797 131 887 406
# person 997 243 1063 411
# ...............................
# person 283 264 352 471
# person 196 273 256 477
# ...............................
# person 807 381 895 660
# person 334 315 447 592
# person 905 297 985 581
# ...............................
# person 220 171 319 459
# ...............................
# person 609 287 752 789
# person 439 318 591 790
# person 810 275 902 704
# person 761 293 817 465
# ...............................
# person 549 177 710 717
# person 91 219 284 772
# person 759 199 959 791
# ...............................
# person 601 228 713 731
# person 538 185 633 718
# person 275 224 432 690
# ...............................
# person 331 202 436 497
# ...............................
# person 304 222 461 696
# ...............................
# person 374 189 434 378
# person 304 185 366 385
# person 234 192 293 379
# ...............................
# person 636 228 711 468
# ...............................
# person 305 312 418 671
# ...............................
# person 426 239 526 584
# person 278 240 486 593
# ...............................
# person 671 323 723 448
# person 637 324 683 449
# person 271 312 330 472
# person 229 313 292 479
# ...............................
# person 769 232 905 571
# person 580 252 676 555
# person 417 251 521 550
# person 178 238 293 540
# person 292 226 422 547
# ...............................
# person 612 376 731 775
# person 787 429 903 768
# person 419 413 563 689
# person 244 396 385 767
# person 210 202 323 557
# person 949 477 1040 779
# person 883 556 962 811
# ...............................
# person 203 174 287 470
# person 283 194 383 464
# person 553 164 655 462
# person 696 167 768 400
# person 779 169 872 426
# ...............................
# person 216 170 316 507
# person 350 150 451 475
# ...............................
# person 244 98 306 232
# ...............................
# person 598 177 767 898
# person 966 294 1028 523
# ...............................
# person 444 277 601 794
# person 102 315 228 785
# person 800 78 844 219
# ...............................
# person 740 105 961 893
# ...............................
# person 393 259 509 647
# person 476 212 588 672
# ...............................
# person 222 257 306 557
# person 46 240 157 542
# ...............................
# person 503 359 593 570
# person 617 381 717 681
# person 829 399 918 688
# person 913 388 982 575
# ...............................
# person 360 379 458 741
# person 454 368 545 742
# person 753 424 849 736
# person 855 444 960 746
# person 946 451 1045 746
# person 148 422 179 521
# person 166 419 206 517
# ...............................
# person 244 280 394 802
# person 134 345 267 839
# ...............................
# person 373 181 453 430
# ...............................
# person 215 152 276 338
# person 80 156 154 438
# person 156 69 182 141
# person 127 70 155 133
# ...............................
# person 201 207 254 394
# person 173 211 219 382
# ...............................
# person 139 107 244 480
# ...............................
# person 166 114 324 569
# ...............................
# person 173 74 322 598
# ...............................
# person 212 151 304 566
# person 40 241 82 326
# ...............................
# person 162 155 305 503
# ...............................
# person 212 198 280 471
# ...............................
# person 190 218 330 524
# ...............................
# person 159 115 324 569
# person 36 109 75 221
# ...............................
# person 200 191 284 398
# ...............................
# person 158 51 336 635
# ...............................
# person 144 68 322 635
# ...............................
# person 80 85 253 602
# ...............................
# person 116 54 277 633
# ...............................
# person 152 54 332 631
# ...............................
# person 142 119 312 635
# ...............................
# person 116 53 290 630
# ...............................
# person 191 83 371 586
# ...............................
# person 230 229 321 539
# ...............................
# person 217 200 346 534
# ...............................
# person 196 232 270 413
# ...............................
# person 172 152 309 490
# ...............................
# person 282 104 405 436
# ...............................
# person 293 114 363 438
# ...............................
# person 291 121 398 426
# ...............................
# person 273 144 389 470
# ...............................
# person 297 76 415 434
# ...............................
# person 319 132 398 380
# ...............................
# person 305 127 396 411
# ...............................
# person 387 154 507 428
# ...............................
# person 313 173 405 414
# ...............................
# person 252 131 357 471
# ...............................
# person 261 125 352 456
# ...............................
# person 217 138 313 413
# ...............................
# person 197 71 314 429
# ...............................
# person 287 201 410 423
# ...............................
# person 262 183 337 355
# ...............................
# person 264 133 386 437
# ...............................
# person 233 157 374 559
# person 139 176 228 498
# ...............................
# person 226 187 339 551
# ...............................
# person 157 128 296 551
# person 352 138 408 327
# person 310 135 370 318
# person 402 147 454 317
# ...............................
# person 181 169 304 484
# ...............................
# person 225 164 322 528
# ...............................
# person 192 123 327 534
# ...............................
# person 254 138 388 530
# person 102 136 226 519
# ...............................
# person 173 127 336 567
# ...............................
# person 150 98 333 578
# person 336 123 407 301
# ...............................
# person 370 43 445 266
# person 339 67 384 254
# person 192 97 341 536
# ...............................
# person 287 98 451 536
# person 41 127 153 506
# person 127 145 239 511
# ...............................
# person 194 128 334 558
# ...............................
# person 141 222 246 474
# person 323 225 400 469
# ...............................
# person 153 198 276 514
# person 277 208 387 505
# person 270 179 307 260
# ...............................
# person 216 125 356 503
# person 113 124 235 491
# ...............................
# person 220 107 404 604
# person 58 198 207 598
# ...............................
# person 266 133 373 557
# person 42 79 178 578
# person 150 103 253 526
# ...............................
# person 184 208 252 390
# person 133 216 191 388
# ...............................
# person 242 163 355 439
# person 154 180 273 463
# ...............................
# person 207 224 283 462
# ...............................
# person 333 78 451 402
# person 242 113 334 402
# person 125 86 155 165
# person 94 87 121 160
# person 150 91 176 165
# ...............................
# person 380 182 433 327
# person 455 177 512 330
# person 286 182 342 332
# person 234 181 283 324
# person 196 182 253 329
# person 98 207 154 336
# person 271 196 307 321
# ...............................
# person 219 124 345 444
# person 327 107 447 439
# person 485 91 523 201
# person 416 89 457 194
# person 140 102 163 171
# ...............................
# person 319 141 389 393
# person 257 157 321 396
# person 172 142 262 396
# ...............................
# person 322 130 401 384
# person 219 142 315 395
# ...............................
# person 305 85 365 301
# person 209 92 284 304
# person 152 100 215 303
# person 108 65 188 287
# person 380 124 429 293
# ...............................
# person 175 72 303 373
# person 338 63 435 368
# person 487 45 564 372
# ...............................
# person 203 185 258 334
# person 262 181 311 321
# person 303 156 377 346
# person 369 179 432 341
# person 445 169 511 320
# ...............................
# person 271 103 387 439
# ...............................
# person 247 148 340 390
# ...............................
# person 247 172 334 389
# person 337 162 414 384
# ...............................
# person 262 170 328 341
# person 208 179 268 340
# person 352 182 404 356
# person 413 188 474 372
# person 461 218 509 362
# person 2 194 40 279
# ...............................
# person 260 121 375 429
# person 353 132 434 411
# ...............................
# person 259 145 334 367
# person 121 126 211 362
# person 348 140 473 418
# person 427 123 525 366
# ...............................
# person 402 172 472 387
# person 475 179 546 366
# person 328 184 391 363
# person 219 173 264 296
# person 184 181 220 298
# person 263 201 305 293
# ...............................
# person 176 147 275 427
# person 322 158 411 382
# person 560 160 611 281
# person 424 188 477 295
# ...............................
# person 258 187 325 358
# person 349 176 408 353
# person 398 175 460 338
# person 312 197 356 355
# ...............................
# person 183 82 305 446
# person 318 103 429 431
# ...............................
# person 75 218 113 351
# person 102 195 145 338
# person 171 196 210 342
# person 189 201 230 344
# person 221 203 267 351
# person 247 197 299 355
# person 303 197 350 354
# person 360 210 414 351
# person 414 195 465 351
# person 445 206 492 345
# person 329 212 373 343
# person 477 218 524 350
# person 512 195 557 292
# person 556 198 602 295
# person 597 196 637 307
# person 140 197 175 330
# ...............................
# person 89 70 181 318
# person 235 160 324 393
# person 321 98 464 407
# person 503 95 566 281
# person 447 103 489 215
# person 559 121 636 396
# ...............................
# person 307 178 397 449
# ...............................
# person 305 168 361 324
# person 185 173 235 316
# person 279 227 323 333
# person 246 186 300 298
# person 417 181 482 411
# person 98 181 145 331
# ...............................
# person 256 155 333 398
# person 331 142 408 394
# person 473 139 524 259
# ...............................
# person 302 166 366 356
# ...............................
# person 352 126 433 458
# person 214 137 307 389
# ...............................
# person 238 214 328 445
# person 52 192 112 394
# person 157 195 217 378
# person 432 182 509 389
# person 371 194 426 392
# ...............................
# person 217 103 343 475
# person 333 134 416 394
# ...............................
# person 170 84 265 451
# person 402 69 503 441
# person 324 80 395 283
# ...............................
# person 412 127 524 449
# person 251 124 375 440
# person 146 135 219 322
# person 115 153 142 238
# person 228 140 259 234
# ...............................
# person 312 138 396 406
# person 206 153 264 321
# person 93 141 157 312
# person 146 184 197 321
# person 442 156 495 337
# person 482 170 524 358
# person 530 153 607 363
# person 98 208 142 320
# ...............................
# person 277 89 404 458
# person 193 26 296 443
# ...............................
# person 258 144 316 386
# person 317 153 396 375
# ...............................
# person 256 128 380 433
# person 370 174 485 432
# ...............................
# person 216 182 292 422
# person 282 178 356 419
# person 414 169 488 414
# person 468 168 538 415
# ...............................
# person 221 102 344 460
# person 369 100 465 408
# person 125 98 209 406
# ...............................
# person 323 78 469 448
# person 206 77 331 434
# person 473 91 524 270
# ...............................
# person 215 149 305 389
# person 406 158 479 384
# ...............................
# person 284 134 381 451
# person 172 127 283 459
# person 63 129 166 422
# person 8 188 60 342
# person 345 159 428 404
# ...............................
# person 70 76 168 391
# person 301 189 379 393
# person 390 168 469 394
# person 490 178 565 394
# ...............................
# person 41 66 170 471
# person 182 59 275 472
# person 298 49 440 468
# person 441 41 550 439
# ...............................
# person 245 162 357 404
# person 334 145 400 334
# person 457 158 504 304
# person 498 151 548 302
# ...............................
# person 253 136 350 422
# person 82 139 131 232
# ...............................
# person 293 152 427 438
# ...............................
# person 257 103 367 403
# person 171 112 228 259
# person 114 118 167 260
# ...............................
# person 371 134 470 431
# person 244 146 353 476
# person 144 149 223 390
# person 476 121 524 282
# person 202 127 265 346
# person 112 114 179 331
# ...............................
# person 254 147 358 428
# person 155 136 252 457
# person 424 165 456 256
# ...............................
# person 183 128 249 395
# person 480 111 589 443
# ...............................
# person 335 204 411 394
# person 473 188 524 330
# person 518 186 577 333
# ...............................
# person 323 193 422 475
# person 279 210 350 456
# ...............................
# person 324 147 404 385
# person 190 160 296 395
# person 180 137 215 216
# ...............................
# person 212 109 299 368
# person 304 124 369 351
# ...............................
# person 251 107 384 419
# person 130 77 260 417
# ...............................
# person 218 120 332 400
# person 126 117 235 388
# ...............................
# person 263 158 359 378
# person 233 159 263 273
# person 172 144 227 274
# ...............................
# person 367 104 460 376
# person 280 128 382 376
# person 121 126 152 222
# person 74 133 104 208
# ...............................
# person 312 181 386 397
# person 186 145 244 354
# person 73 138 134 315
# person 143 165 188 312
# person 253 154 343 353
# ...............................
# person 254 118 361 398
# person 423 162 516 365
# person 360 141 385 219
# ...............................
# person 144 77 240 469
# person 40 79 146 473
# person 275 95 397 463
# person 510 113 581 439
# ...............................
# person 126 19 337 636
# ...............................
# person 198 61 331 404
# person 88 49 132 155
# ...............................
# person 213 83 304 429
# person 344 81 450 431
# person 5 71 67 227
# ...............................
# person 301 73 438 375
# person 545 98 578 185
# ...............................
# person 299 136 380 325
# person 238 119 308 326
# ...............................
# person 474 117 521 237
# person 443 126 473 227
# person 253 135 358 420
# person 332 123 363 189
# person 378 116 401 176
# person 394 112 422 173
# ...............................
# person 571 120 610 265
# person 204 153 304 468
# ...............................
# person 172 142 248 417
# person 264 131 344 410
# ...............................
# person 307 131 376 330
# person 70 125 142 276
# person 449 118 620 460
# person 273 126 327 289
# ...............................
# person 299 46 418 397
# ...............................
# person 311 39 412 388
# ...............................
# person 278 71 403 375
# ...............................
# person 180 35 351 458
# ...............................
# person 202 44 354 369
# ...............................
# person 292 56 392 404
# ...............................
# person 212 47 328 396
# ...............................
# person 297 36 418 395
# ...............................
# person 253 34 446 469
# ...............................
# person 267 80 399 417
# ...............................
# person 265 29 409 443
# ...............................
# person 249 20 366 449
# ...............................
# person 208 54 371 425
# ...............................
# person 223 65 346 396
# ...............................
# person 291 37 433 390
# ...............................
# person 243 47 361 397
# ...............................
# person 182 49 275 402
# ...............................
# person 259 52 358 403
# ...............................
# person 244 33 381 407
# ...............................
# person 280 45 429 441
# ...............................
# person 271 40 402 428
# ...............................
# person 242 44 432 435
# ...............................
# person 210 37 422 406
# ...............................
# person 205 36 323 318
# ...............................
# person 242 40 354 397
# ...............................
# person 230 51 381 372
# ...............................
# person 289 38 404 453
# ...............................
# person 238 53 345 412
# ...............................
# person 262 51 391 475
# ...............................
# person 384 46 494 414
# ...............................
# person 233 47 333 443
# ...............................
# person 319 40 411 385
# person 144 25 219 254
# ...............................
# person 376 25 465 342
# ...............................
# person 287 51 409 449
# ...............................
# person 378 41 518 475
# ...............................
# person 280 40 421 469
# ...............................
# person 299 31 434 418
# ...............................
# person 237 33 394 457
# ...............................
# person 285 51 429 475
# ...............................
# person 266 70 430 476
# ...............................
# person 278 56 432 441
# ...............................
# person 269 21 429 432
# ...............................
# person 301 53 443 449
# ...............................
# person 208 50 360 391
# ...............................
# person 137 57 229 410
# ...............................
# person 164 35 366 385
# ...............................
# person 229 35 407 362
# ...............................
# person 245 42 372 377
# ...............................
# person 237 51 373 394
# ...............................
# person 179 52 315 400
# ...............................
# person 201 41 335 388
# ...............................
# person 285 19 459 475
# ...............................
# person 195 12 410 424
# ...............................
# person 209 9 411 417
# ...............................
# person 223 10 395 374
# ...............................
# person 203 49 387 381
# ...............................
# person 236 35 358 415
# ...............................
# person 275 31 444 371
# ...............................
# person 264 60 480 443
# ...............................
# person 240 43 416 385
# ...............................
# person 239 47 416 398
# ...............................
# person 209 37 412 447
# ...............................
# person 189 5 406 371
# ...............................
# person 187 38 372 379
# ...............................
# person 272 2 407 385
# ...............................
# person 200 16 467 382
# ...............................
# person 190 0 381 370
# ...............................
# person 180 1 354 394
# ...............................
# person 235 46 394 452
# ...............................
# person 274 139 373 406
# person 355 140 454 412
# person 106 134 175 292
# person 528 149 558 231
# ...............................
# person 255 118 355 402
# person 351 141 430 405
# ...............................
# person 382 153 455 368
# person 326 159 393 379
# person 202 170 277 359
# person 111 165 186 359
# ...............................
# person 250 146 339 382
# ...............................
# person 221 52 334 427
# ...............................
# person 204 176 304 446
# ...............................
# person 386 145 466 416
# ...............................
# person 258 61 400 452
# ...............................
# person 264 39 423 469
# ...............................
# person 233 49 383 418
# ...............................
# person 230 55 389 431
# ...............................
# person 163 35 315 443
# ...............................
# person 215 37 390 444
# ...............................
# person 230 37 383 364
# ...............................
# person 69 128 289 597
# ...............................
# person 250 180 327 405
# person 317 184 408 396
# ...............................
# person 336 184 408 365
# person 288 188 327 278
# ...............................
# person 224 90 385 470
# ...............................
# person 211 144 308 370
# person 283 127 390 384
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................
# ...............................

# %%
# get_gt_txt.py
#----------------------------------------------------#
#   获取测试集的ground-truth
#   具体视频教程可查看
#   https://www.bilibili.com/video/BV1zE411u7Vw
#----------------------------------------------------#
import sys
import os
import glob
import xml.etree.ElementTree as ET

'''
！！！！！！！！！！！！！注意事项！！！！！！！！！！！！！
# 这一部分是当xml有无关的类的时候，下方有代码可以进行筛选！
'''
#---------------------------------------------------#
#   获得类
#---------------------------------------------------#
def get_classes(classes_path):
    '''loads the classes'''
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

image_ids = open('VOCdevkit/VOC2007/ImageSets/Main/test.txt').read().strip().split()

if not os.path.exists("./input"):
    os.makedirs("./input")
if not os.path.exists("./input/ground-truth"):
    os.makedirs("./input/ground-truth")

for image_id in image_ids:
    with open("./input/ground-truth/"+image_id+".txt", "w") as new_f:
        root = ET.parse("VOCdevkit/VOC2007/Annotations/"+image_id+".xml").getroot()
        for obj in root.findall('object'):
            difficult_flag = False
            if obj.find('difficult')!=None:
                difficult = obj.find('difficult').text
                if int(difficult)==1:
                    difficult_flag = True
            obj_name = obj.find('name').text
            '''
            ！！！！！！！！！！！！注意事项！！！！！！！！！！！！
            # 这一部分是当xml有无关的类的时候，可以取消下面代码的注释
            # 利用对应的classes.txt来进行筛选！！！！！！！！！！！！
            '''
            # classes_path = 'model_data/voc_classes.txt'
            # class_names = get_classes(classes_path)
            # if obj_name not in class_names:
            #     continue

            bndbox = obj.find('bndbox')
            left = bndbox.find('xmin').text
            top = bndbox.find('ymin').text
            right = bndbox.find('xmax').text
            bottom = bndbox.find('ymax').text

            if difficult_flag:
                new_f.write("%s %s %s %s %s difficult\n" % (obj_name, left, top, right, bottom))
            else:
                new_f.write("%s %s %s %s %s\n" % (obj_name, left, top, right, bottom))

print("Conversion completed!")

# %%
# 最後在terminal上執行get_mAP.py
import glob
import json
import os
import shutil
import operator
import sys
import argparse
import math

import numpy as np

'''
用于计算mAP
代码克隆自https://github.com/Cartucho/mAP
如果想要设定mAP0.x，比如计算mAP0.75，可以设定MINOVERLAP = 0.75。
'''
MINOVERLAP = 0.5

parser = argparse.ArgumentParser()
parser.add_argument('-na', '--no-animation', help="no animation is shown.", action="store_true")
parser.add_argument('-np', '--no-plot', help="no plot is shown.", action="store_true")
parser.add_argument('-q', '--quiet', help="minimalistic console output.", action="store_true")
parser.add_argument('-i', '--ignore', nargs='+', type=str, help="ignore a list of classes.")
parser.add_argument('--set-class-iou', nargs='+', type=str, help="set IoU for a specific class.")
args = parser.parse_args()

'''
    0,0 ------> x (width)
     |
     |  (Left,Top)
     |      *_________
     |      |         |
            |         |
     y      |_________|
  (height)            *
                (Right,Bottom)
'''

if args.ignore is None:
    args.ignore = []

specific_iou_flagged = False
if args.set_class_iou is not None:
    specific_iou_flagged = True

os.chdir(os.path.dirname(os.path.abspath(__file__)))

GT_PATH = os.path.join(os.getcwd(), 'input', 'ground-truth')
DR_PATH = os.path.join(os.getcwd(), 'input', 'detection-results')
IMG_PATH = os.path.join(os.getcwd(), 'input', 'images-optional')
if os.path.exists(IMG_PATH): 
    for dirpath, dirnames, files in os.walk(IMG_PATH):
        if not files:
            args.no_animation = True
else:
    args.no_animation = True

show_animation = False
if not args.no_animation:
    try:
        import cv2
        show_animation = True
    except ImportError:
        print("\"opencv-python\" not found, please install to visualize the results.")
        args.no_animation = True

draw_plot = False
if not args.no_plot:
    try:
        import matplotlib.pyplot as plt
        draw_plot = True
    except ImportError:
        print("\"matplotlib\" not found, please install it to get the resulting plots.")
        args.no_plot = True


def log_average_miss_rate(precision, fp_cumsum, num_images):
    """
        log-average miss rate:
            Calculated by averaging miss rates at 9 evenly spaced FPPI points
            between 10e-2 and 10e0, in log-space.
        output:
                lamr | log-average miss rate
                mr | miss rate
                fppi | false positives per image
        references:
            [1] Dollar, Piotr, et al. "Pedestrian Detection: An Evaluation of the
               State of the Art." Pattern Analysis and Machine Intelligence, IEEE
               Transactions on 34.4 (2012): 743 - 761.
    """

    if precision.size == 0:
        lamr = 0
        mr = 1
        fppi = 0
        return lamr, mr, fppi

    fppi = fp_cumsum / float(num_images)
    mr = (1 - precision)

    fppi_tmp = np.insert(fppi, 0, -1.0)
    mr_tmp = np.insert(mr, 0, 1.0)

    ref = np.logspace(-2.0, 0.0, num = 9)
    for i, ref_i in enumerate(ref):
        j = np.where(fppi_tmp <= ref_i)[-1][-1]
        ref[i] = mr_tmp[j]

    lamr = math.exp(np.mean(np.log(np.maximum(1e-10, ref))))

    return lamr, mr, fppi

"""
 throw error and exit
"""
def error(msg):
    print(msg)
    sys.exit(0)

"""
 check if the number is a float between 0.0 and 1.0
"""
def is_float_between_0_and_1(value):
    try:
        val = float(value)
        if val > 0.0 and val < 1.0:
            return True
        else:
            return False
    except ValueError:
        return False

"""
 Calculate the AP given the recall and precision array
    1st) We compute a version of the measured precision/recall curve with
         precision monotonically decreasing
    2nd) We compute the AP as the area under this curve by numerical integration.
"""
def voc_ap(rec, prec):
    """
    --- Official matlab code VOC2012---
    mrec=[0 ; rec ; 1];
    mpre=[0 ; prec ; 0];
    for i=numel(mpre)-1:-1:1
            mpre(i)=max(mpre(i),mpre(i+1));
    end
    i=find(mrec(2:end)~=mrec(1:end-1))+1;
    ap=sum((mrec(i)-mrec(i-1)).*mpre(i));
    """
    rec.insert(0, 0.0) # insert 0.0 at begining of list
    rec.append(1.0) # insert 1.0 at end of list
    mrec = rec[:]
    prec.insert(0, 0.0) # insert 0.0 at begining of list
    prec.append(0.0) # insert 0.0 at end of list
    mpre = prec[:]
    """
     This part makes the precision monotonically decreasing
        (goes from the end to the beginning)
        matlab: for i=numel(mpre)-1:-1:1
                    mpre(i)=max(mpre(i),mpre(i+1));
    """
    for i in range(len(mpre)-2, -1, -1):
        mpre[i] = max(mpre[i], mpre[i+1])
    """
     This part creates a list of indexes where the recall changes
        matlab: i=find(mrec(2:end)~=mrec(1:end-1))+1;
    """
    i_list = []
    for i in range(1, len(mrec)):
        if mrec[i] != mrec[i-1]:
            i_list.append(i) # if it was matlab would be i + 1
    """
     The Average Precision (AP) is the area under the curve
        (numerical integration)
        matlab: ap=sum((mrec(i)-mrec(i-1)).*mpre(i));
    """
    ap = 0.0
    for i in i_list:
        ap += ((mrec[i]-mrec[i-1])*mpre[i])
    return ap, mrec, mpre


"""
 Convert the lines of a file to a list
"""
def file_lines_to_list(path):
    # open txt file lines to a list
    with open(path) as f:
        content = f.readlines()
    # remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    return content

"""
 Draws text in image
"""
def draw_text_in_image(img, text, pos, color, line_width):
    font = cv2.FONT_HERSHEY_PLAIN
    fontScale = 1
    lineType = 1
    bottomLeftCornerOfText = pos
    cv2.putText(img, text,
            bottomLeftCornerOfText,
            font,
            fontScale,
            color,
            lineType)
    text_width, _ = cv2.getTextSize(text, font, fontScale, lineType)[0]
    return img, (line_width + text_width)

"""
 Plot - adjust axes
"""
def adjust_axes(r, t, fig, axes):
    # get text width for re-scaling
    bb = t.get_window_extent(renderer=r)
    text_width_inches = bb.width / fig.dpi
    # get axis width in inches
    current_fig_width = fig.get_figwidth()
    new_fig_width = current_fig_width + text_width_inches
    propotion = new_fig_width / current_fig_width
    # get axis limit
    x_lim = axes.get_xlim()
    axes.set_xlim([x_lim[0], x_lim[1]*propotion])

"""
 Draw plot using Matplotlib
"""
def draw_plot_func(dictionary, n_classes, window_title, plot_title, x_label, output_path, to_show, plot_color, true_p_bar):
    # sort the dictionary by decreasing value, into a list of tuples
    sorted_dic_by_value = sorted(dictionary.items(), key=operator.itemgetter(1))
    # unpacking the list of tuples into two lists
    sorted_keys, sorted_values = zip(*sorted_dic_by_value)
    # 
    if true_p_bar != "":
        """
         Special case to draw in:
            - green -> TP: True Positives (object detected and matches ground-truth)
            - red -> FP: False Positives (object detected but does not match ground-truth)
            - orange -> FN: False Negatives (object not detected but present in the ground-truth)
        """
        fp_sorted = []
        tp_sorted = []
        for key in sorted_keys:
            fp_sorted.append(dictionary[key] - true_p_bar[key])
            tp_sorted.append(true_p_bar[key])
        plt.barh(range(n_classes), fp_sorted, align='center', color='crimson', label='False Positive')
        plt.barh(range(n_classes), tp_sorted, align='center', color='forestgreen', label='True Positive', left=fp_sorted)
        # add legend
        plt.legend(loc='lower right')
        """
         Write number on side of bar
        """
        fig = plt.gcf() # gcf - get current figure
        axes = plt.gca()
        r = fig.canvas.get_renderer()
        for i, val in enumerate(sorted_values):
            fp_val = fp_sorted[i]
            tp_val = tp_sorted[i]
            fp_str_val = " " + str(fp_val)
            tp_str_val = fp_str_val + " " + str(tp_val)
            # trick to paint multicolor with offset:
            # first paint everything and then repaint the first number
            t = plt.text(val, i, tp_str_val, color='forestgreen', va='center', fontweight='bold')
            plt.text(val, i, fp_str_val, color='crimson', va='center', fontweight='bold')
            if i == (len(sorted_values)-1): # largest bar
                adjust_axes(r, t, fig, axes)
    else:
        plt.barh(range(n_classes), sorted_values, color=plot_color)
        """
         Write number on side of bar
        """
        fig = plt.gcf() # gcf - get current figure
        axes = plt.gca()
        r = fig.canvas.get_renderer()
        for i, val in enumerate(sorted_values):
            str_val = " " + str(val) # add a space before
            if val < 1.0:
                str_val = " {0:.2f}".format(val)
            t = plt.text(val, i, str_val, color=plot_color, va='center', fontweight='bold')
            # re-set axes to show number inside the figure
            if i == (len(sorted_values)-1): # largest bar
                adjust_axes(r, t, fig, axes)
    # set window title
    fig.canvas.set_window_title(window_title)
    # write classes in y axis
    tick_font_size = 12
    plt.yticks(range(n_classes), sorted_keys, fontsize=tick_font_size)
    """
     Re-scale height accordingly
    """
    init_height = fig.get_figheight()
    # comput the matrix height in points and inches
    dpi = fig.dpi
    height_pt = n_classes * (tick_font_size * 1.4) # 1.4 (some spacing)
    height_in = height_pt / dpi
    # compute the required figure height 
    top_margin = 0.15 # in percentage of the figure height
    bottom_margin = 0.05 # in percentage of the figure height
    figure_height = height_in / (1 - top_margin - bottom_margin)
    # set new height
    if figure_height > init_height:
        fig.set_figheight(figure_height)

    # set plot title
    plt.title(plot_title, fontsize=14)
    # set axis titles
    # plt.xlabel('classes')
    plt.xlabel(x_label, fontsize='large')
    # adjust size of window
    fig.tight_layout()
    # save the plot
    fig.savefig(output_path)
    # show image
    if to_show:
        plt.show()
    # close the plot
    plt.close()

"""
 Create a ".temp_files/" and "results/" directory
"""
TEMP_FILES_PATH = ".temp_files"
if not os.path.exists(TEMP_FILES_PATH): # if it doesn't exist already
    os.makedirs(TEMP_FILES_PATH)
results_files_path = "results"
if os.path.exists(results_files_path): # if it exist already
    # reset the results directory
    shutil.rmtree(results_files_path)

os.makedirs(results_files_path)
if draw_plot:
    os.makedirs(os.path.join(results_files_path, "AP"))
    os.makedirs(os.path.join(results_files_path, "F1"))
    os.makedirs(os.path.join(results_files_path, "Recall"))
    os.makedirs(os.path.join(results_files_path, "Precision"))
if show_animation:
    os.makedirs(os.path.join(results_files_path, "images", "detections_one_by_one"))

"""
 ground-truth
     Load each of the ground-truth files into a temporary ".json" file.
     Create a list of all the class names present in the ground-truth (gt_classes).
"""
# get a list with the ground-truth files
ground_truth_files_list = glob.glob(GT_PATH + '/*.txt')
if len(ground_truth_files_list) == 0:
    error("Error: No ground-truth files found!")
ground_truth_files_list.sort()
# dictionary with counter per class
gt_counter_per_class = {}
counter_images_per_class = {}

for txt_file in ground_truth_files_list:
    #print(txt_file)
    file_id = txt_file.split(".txt", 1)[0]
    file_id = os.path.basename(os.path.normpath(file_id))
    # check if there is a correspondent detection-results file
    temp_path = os.path.join(DR_PATH, (file_id + ".txt"))
    if not os.path.exists(temp_path):
        error_msg = "Error. File not found: {}\n".format(temp_path)
        error_msg += "(You can avoid this error message by running extra/intersect-gt-and-dr.py)"
        error(error_msg)
    lines_list = file_lines_to_list(txt_file)
    # create ground-truth dictionary
    bounding_boxes = []
    is_difficult = False
    already_seen_classes = []
    for line in lines_list:
        try:
            if "difficult" in line:
                class_name, left, top, right, bottom, _difficult = line.split()
                is_difficult = True
            else:
                class_name, left, top, right, bottom = line.split()
                    
        except:
            if "difficult" in line:
                line_split = line.split()
                _difficult = line_split[-1]
                bottom = line_split[-2]
                right = line_split[-3]
                top = line_split[-4]
                left = line_split[-5]
                class_name = ""
                for name in line_split[:-5]:
                    class_name += name + " "
                class_name = class_name[:-1]
                is_difficult = True
            else:
                line_split = line.split()
                bottom = line_split[-1]
                right = line_split[-2]
                top = line_split[-3]
                left = line_split[-4]
                class_name = ""
                for name in line_split[:-4]:
                    class_name += name + " "
                class_name = class_name[:-1]
        if class_name in args.ignore:
            continue
        bbox = left + " " + top + " " + right + " " +bottom
        if is_difficult:
                bounding_boxes.append({"class_name":class_name, "bbox":bbox, "used":False, "difficult":True})
                is_difficult = False
        else:
                bounding_boxes.append({"class_name":class_name, "bbox":bbox, "used":False})
                if class_name in gt_counter_per_class:
                    gt_counter_per_class[class_name] += 1
                else:
                    gt_counter_per_class[class_name] = 1

                if class_name not in already_seen_classes:
                    if class_name in counter_images_per_class:
                        counter_images_per_class[class_name] += 1
                    else:
                        counter_images_per_class[class_name] = 1
                    already_seen_classes.append(class_name)


    with open(TEMP_FILES_PATH + "/" + file_id + "_ground_truth.json", 'w') as outfile:
        json.dump(bounding_boxes, outfile)

gt_classes = list(gt_counter_per_class.keys())
gt_classes = sorted(gt_classes)
n_classes = len(gt_classes)

"""
 Check format of the flag --set-class-iou (if used)
    e.g. check if class exists
"""
if specific_iou_flagged:
    n_args = len(args.set_class_iou)
    error_msg = \
        '\n --set-class-iou [class_1] [IoU_1] [class_2] [IoU_2] [...]'
    if n_args % 2 != 0:
        error('Error, missing arguments. Flag usage:' + error_msg)
    # [class_1] [IoU_1] [class_2] [IoU_2]
    # specific_iou_classes = ['class_1', 'class_2']
    specific_iou_classes = args.set_class_iou[::2] # even
    # iou_list = ['IoU_1', 'IoU_2']
    iou_list = args.set_class_iou[1::2] # odd
    if len(specific_iou_classes) != len(iou_list):
        error('Error, missing arguments. Flag usage:' + error_msg)
    for tmp_class in specific_iou_classes:
        if tmp_class not in gt_classes:
                    error('Error, unknown class \"' + tmp_class + '\". Flag usage:' + error_msg)
    for num in iou_list:
        if not is_float_between_0_and_1(num):
            error('Error, IoU must be between 0.0 and 1.0. Flag usage:' + error_msg)

"""
 detection-results
     Load each of the detection-results files into a temporary ".json" file.
"""
dr_files_list = glob.glob(DR_PATH + '/*.txt')
dr_files_list.sort()

for class_index, class_name in enumerate(gt_classes):
    bounding_boxes = []
    for txt_file in dr_files_list:
        file_id = txt_file.split(".txt",1)[0]
        file_id = os.path.basename(os.path.normpath(file_id))
        temp_path = os.path.join(GT_PATH, (file_id + ".txt"))
        if class_index == 0:
            if not os.path.exists(temp_path):
                error_msg = "Error. File not found: {}\n".format(temp_path)
                error_msg += "(You can avoid this error message by running extra/intersect-gt-and-dr.py)"
                error(error_msg)
        lines = file_lines_to_list(txt_file)
        for line in lines:
            try:
                tmp_class_name, confidence, left, top, right, bottom = line.split()
            except:
                line_split = line.split()
                bottom = line_split[-1]
                right = line_split[-2]
                top = line_split[-3]
                left = line_split[-4]
                confidence = line_split[-5]
                tmp_class_name = ""
                for name in line_split[:-5]:
                    tmp_class_name += name + " "
                tmp_class_name = tmp_class_name[:-1]

            if tmp_class_name == class_name:
                bbox = left + " " + top + " " + right + " " +bottom
                bounding_boxes.append({"confidence":confidence, "file_id":file_id, "bbox":bbox})

    bounding_boxes.sort(key=lambda x:float(x['confidence']), reverse=True)
    with open(TEMP_FILES_PATH + "/" + class_name + "_dr.json", 'w') as outfile:
        json.dump(bounding_boxes, outfile)

"""
 Calculate the AP for each class
"""
sum_AP = 0.0
ap_dictionary = {}
lamr_dictionary = {}
with open(results_files_path + "/results.txt", 'w') as results_file:
    results_file.write("# AP and precision/recall per class\n")
    count_true_positives = {}

    for class_index, class_name in enumerate(gt_classes):
        count_true_positives[class_name] = 0
        """
         Load detection-results of that class
        """
        dr_file = TEMP_FILES_PATH + "/" + class_name + "_dr.json"
        dr_data = json.load(open(dr_file))
        """
         Assign detection-results to ground-truth objects
        """
        nd = len(dr_data)
        tp = [0] * nd
        fp = [0] * nd
        score = [0] * nd
        score05_idx = 0
        for idx, detection in enumerate(dr_data):
            file_id = detection["file_id"]
            score[idx]   = float(detection["confidence"])
            if score[idx] > 0.5:
                score05_idx = idx

            if show_animation:
                ground_truth_img = glob.glob1(IMG_PATH, file_id + ".*")
                if len(ground_truth_img) == 0:
                    error("Error. Image not found with id: " + file_id)
                elif len(ground_truth_img) > 1:
                    error("Error. Multiple image with id: " + file_id)
                else:
                    img = cv2.imread(IMG_PATH + "/" + ground_truth_img[0])
                    img_cumulative_path = results_files_path + "/images/" + ground_truth_img[0]
                    if os.path.isfile(img_cumulative_path):
                        img_cumulative = cv2.imread(img_cumulative_path)
                    else:
                        img_cumulative = img.copy()
                    bottom_border = 60
                    BLACK = [0, 0, 0]
                    img = cv2.copyMakeBorder(img, 0, bottom_border, 0, 0, cv2.BORDER_CONSTANT, value=BLACK)

            gt_file = TEMP_FILES_PATH + "/" + file_id + "_ground_truth.json"
            ground_truth_data = json.load(open(gt_file))
            ovmax = -1
            gt_match = -1
            bb = [ float(x) for x in detection["bbox"].split() ]
            for obj in ground_truth_data:
                if obj["class_name"] == class_name:
                    bbgt = [ float(x) for x in obj["bbox"].split() ]
                    bi = [max(bb[0],bbgt[0]), max(bb[1],bbgt[1]), min(bb[2],bbgt[2]), min(bb[3],bbgt[3])]
                    iw = bi[2] - bi[0] + 1
                    ih = bi[3] - bi[1] + 1
                    if iw > 0 and ih > 0:
                        # compute overlap (IoU) = area of intersection / area of union
                        ua = (bb[2] - bb[0] + 1) * (bb[3] - bb[1] + 1) + (bbgt[2] - bbgt[0]
                                        + 1) * (bbgt[3] - bbgt[1] + 1) - iw * ih
                        ov = iw * ih / ua
                        if ov > ovmax:
                            ovmax = ov
                            gt_match = obj

            if show_animation:
                status = "NO MATCH FOUND!" 
            min_overlap = MINOVERLAP
            if specific_iou_flagged:
                if class_name in specific_iou_classes:
                    index = specific_iou_classes.index(class_name)
                    min_overlap = float(iou_list[index])
            if ovmax >= min_overlap:
                if "difficult" not in gt_match:
                    if not bool(gt_match["used"]):
                        tp[idx] = 1
                        gt_match["used"] = True
                        count_true_positives[class_name] += 1
                        with open(gt_file, 'w') as f:
                                f.write(json.dumps(ground_truth_data))
                        if show_animation:
                            status = "MATCH!"
                    else:
                        fp[idx] = 1
                        if show_animation:
                            status = "REPEATED MATCH!"
            else:
                fp[idx] = 1
                if ovmax > 0:
                    status = "INSUFFICIENT OVERLAP"

            """
             Draw image to show animation
            """
            if show_animation:
                height, widht = img.shape[:2]
                # colors (OpenCV works with BGR)
                white = (255,255,255)
                light_blue = (255,200,100)
                green = (0,255,0)
                light_red = (30,30,255)
                # 1st line
                margin = 10
                v_pos = int(height - margin - (bottom_border / 2.0))
                text = "Image: " + ground_truth_img[0] + " "
                img, line_width = draw_text_in_image(img, text, (margin, v_pos), white, 0)
                text = "Class [" + str(class_index) + "/" + str(n_classes) + "]: " + class_name + " "
                img, line_width = draw_text_in_image(img, text, (margin + line_width, v_pos), light_blue, line_width)
                if ovmax != -1:
                    color = light_red
                    if status == "INSUFFICIENT OVERLAP":
                        text = "IoU: {0:.2f}% ".format(ovmax*100) + "< {0:.2f}% ".format(min_overlap*100)
                    else:
                        text = "IoU: {0:.2f}% ".format(ovmax*100) + ">= {0:.2f}% ".format(min_overlap*100)
                        color = green
                    img, _ = draw_text_in_image(img, text, (margin + line_width, v_pos), color, line_width)
                # 2nd line
                v_pos += int(bottom_border / 2.0)
                rank_pos = str(idx+1) # rank position (idx starts at 0)
                text = "Detection #rank: " + rank_pos + " confidence: {0:.2f}% ".format(float(detection["confidence"])*100)
                img, line_width = draw_text_in_image(img, text, (margin, v_pos), white, 0)
                color = light_red
                if status == "MATCH!":
                    color = green
                text = "Result: " + status + " "
                img, line_width = draw_text_in_image(img, text, (margin + line_width, v_pos), color, line_width)

                font = cv2.FONT_HERSHEY_SIMPLEX
                if ovmax > 0: # if there is intersections between the bounding-boxes
                    bbgt = [ int(round(float(x))) for x in gt_match["bbox"].split() ]
                    cv2.rectangle(img,(bbgt[0],bbgt[1]),(bbgt[2],bbgt[3]),light_blue,2)
                    cv2.rectangle(img_cumulative,(bbgt[0],bbgt[1]),(bbgt[2],bbgt[3]),light_blue,2)
                    cv2.putText(img_cumulative, class_name, (bbgt[0],bbgt[1] - 5), font, 0.6, light_blue, 1, cv2.LINE_AA)
                bb = [int(i) for i in bb]
                cv2.rectangle(img,(bb[0],bb[1]),(bb[2],bb[3]),color,2)
                cv2.rectangle(img_cumulative,(bb[0],bb[1]),(bb[2],bb[3]),color,2)
                cv2.putText(img_cumulative, class_name, (bb[0],bb[1] - 5), font, 0.6, color, 1, cv2.LINE_AA)
                # show image
                cv2.imshow("Animation", img)
                cv2.waitKey(20) # show for 20 ms
                # save image to results
                output_img_path = results_files_path + "/images/detections_one_by_one/" + class_name + "_detection" + str(idx) + ".jpg"
                cv2.imwrite(output_img_path, img)
                # save the image with all the objects drawn to it
                cv2.imwrite(img_cumulative_path, img_cumulative)

        cumsum = 0
        for idx, val in enumerate(fp):
            fp[idx] += cumsum
            cumsum += val

        cumsum = 0
        for idx, val in enumerate(tp):
            tp[idx] += cumsum
            cumsum += val

        rec = tp[:]
        for idx, val in enumerate(tp):
            rec[idx] = float(tp[idx]) / np.maximum(gt_counter_per_class[class_name], 1)

        prec = tp[:]
        for idx, val in enumerate(tp):
            prec[idx] = float(tp[idx]) / np.maximum((fp[idx] + tp[idx]), 1)

        ap, mrec, mprec = voc_ap(rec[:], prec[:])
        F1 = np.array(rec)*np.array(prec)*2 / np.where((np.array(prec)+np.array(rec))==0, 1, (np.array(prec)+np.array(rec)))

        sum_AP += ap
        text = "{0:.2f}%".format(ap*100) + " = " + class_name + " AP " #class_name + " AP = {0:.2f}%".format(ap*100)

        if len(prec)>0:
            F1_text = "{0:.2f}".format(F1[score05_idx]) + " = " + class_name + " F1 "
            Recall_text = "{0:.2f}%".format(rec[score05_idx]*100) + " = " + class_name + " Recall "
            Precision_text = "{0:.2f}%".format(prec[score05_idx]*100) + " = " + class_name + " Precision "
        else:
            F1_text = "0.00" + " = " + class_name + " F1 " 
            Recall_text = "0.00%" + " = " + class_name + " Recall " 
            Precision_text = "0.00%" + " = " + class_name + " Precision " 

        rounded_prec = [ '%.2f' % elem for elem in prec ]
        rounded_rec = [ '%.2f' % elem for elem in rec ]
        results_file.write(text + "\n Precision: " + str(rounded_prec) + "\n Recall :" + str(rounded_rec) + "\n\n")
        if not args.quiet:
            if len(prec)>0:
                print(text + "\t||\tscore_threhold=0.5 : " + "F1=" + "{0:.2f}".format(F1[score05_idx])\
                    + " ; Recall=" + "{0:.2f}%".format(rec[score05_idx]*100) + " ; Precision=" + "{0:.2f}%".format(prec[score05_idx]*100))
            else:
                print(text + "\t||\tscore_threhold=0.5 : F1=0.00% ; Recall=0.00% ; Precision=0.00%")
        ap_dictionary[class_name] = ap

        n_images = counter_images_per_class[class_name]
        lamr, mr, fppi = log_average_miss_rate(np.array(rec), np.array(fp), n_images)
        lamr_dictionary[class_name] = lamr

        """
         Draw plot
        """
        if draw_plot:
            plt.plot(rec, prec, '-o')
            area_under_curve_x = mrec[:-1] + [mrec[-2]] + [mrec[-1]]
            area_under_curve_y = mprec[:-1] + [0.0] + [mprec[-1]]
            plt.fill_between(area_under_curve_x, 0, area_under_curve_y, alpha=0.2, edgecolor='r')

            fig = plt.gcf()
            fig.canvas.set_window_title('AP ' + class_name)

            plt.title('class: ' + text)
            plt.xlabel('Recall')
            plt.ylabel('Precision')
            axes = plt.gca()
            axes.set_xlim([0.0,1.0])
            axes.set_ylim([0.0,1.05]) 
            fig.savefig(results_files_path + "/AP/" + class_name + ".png")
            plt.cla()

            plt.plot(score, F1, "-", color='orangered')
            plt.title('class: ' + F1_text + "\nscore_threhold=0.5")
            plt.xlabel('Score_Threhold')
            plt.ylabel('F1')
            axes = plt.gca()
            axes.set_xlim([0.0,1.0])
            axes.set_ylim([0.0,1.05])
            fig.savefig(results_files_path + "/F1/" + class_name + ".png")
            plt.cla()

            plt.plot(score, rec, "-H", color='gold')
            plt.title('class: ' + Recall_text + "\nscore_threhold=0.5")
            plt.xlabel('Score_Threhold')
            plt.ylabel('Recall')
            axes = plt.gca()
            axes.set_xlim([0.0,1.0])
            axes.set_ylim([0.0,1.05])
            fig.savefig(results_files_path + "/Recall/" + class_name + ".png")
            plt.cla()

            plt.plot(score, prec, "-s", color='palevioletred')
            plt.title('class: ' + Precision_text + "\nscore_threhold=0.5")
            plt.xlabel('Score_Threhold')
            plt.ylabel('Precision')
            axes = plt.gca()
            axes.set_xlim([0.0,1.0])
            axes.set_ylim([0.0,1.05])
            fig.savefig(results_files_path + "/Precision/" + class_name + ".png")
            plt.cla()
            
    if show_animation:
        cv2.destroyAllWindows()

    results_file.write("\n# mAP of all classes\n")
    mAP = sum_AP / n_classes
    text = "mAP = {0:.2f}%".format(mAP*100)
    results_file.write(text + "\n")
    print(text)

# remove the temp_files directory
shutil.rmtree(TEMP_FILES_PATH)

"""
 Count total of detection-results
"""
# iterate through all the files
det_counter_per_class = {}
for txt_file in dr_files_list:
    # get lines to list
    lines_list = file_lines_to_list(txt_file)
    for line in lines_list:
        class_name = line.split()[0]
        # check if class is in the ignore list, if yes skip
        if class_name in args.ignore:
            continue
        # count that object
        if class_name in det_counter_per_class:
            det_counter_per_class[class_name] += 1
        else:
            # if class didn't exist yet
            det_counter_per_class[class_name] = 1
#print(det_counter_per_class)
dr_classes = list(det_counter_per_class.keys())


"""
 Plot the total number of occurences of each class in the ground-truth
"""
if draw_plot:
    window_title = "ground-truth-info"
    plot_title = "ground-truth\n"
    plot_title += "(" + str(len(ground_truth_files_list)) + " files and " + str(n_classes) + " classes)"
    x_label = "Number of objects per class"
    output_path = results_files_path + "/ground-truth-info.png"
    to_show = False
    plot_color = 'forestgreen'
    draw_plot_func(
        gt_counter_per_class,
        n_classes,
        window_title,
        plot_title,
        x_label,
        output_path,
        to_show,
        plot_color,
        '',
        )

"""
 Write number of ground-truth objects per class to results.txt
"""
with open(results_files_path + "/results.txt", 'a') as results_file:
    results_file.write("\n# Number of ground-truth objects per class\n")
    for class_name in sorted(gt_counter_per_class):
        results_file.write(class_name + ": " + str(gt_counter_per_class[class_name]) + "\n")

"""
 Finish counting true positives
"""
for class_name in dr_classes:
    # if class exists in detection-result but not in ground-truth then there are no true positives in that class
    if class_name not in gt_classes:
        count_true_positives[class_name] = 0
#print(count_true_positives)

"""
 Plot the total number of occurences of each class in the "detection-results" folder
"""
if draw_plot:
    window_title = "detection-results-info"
    # Plot title
    plot_title = "detection-results\n"
    plot_title += "(" + str(len(dr_files_list)) + " files and "
    count_non_zero_values_in_dictionary = sum(int(x) > 0 for x in list(det_counter_per_class.values()))
    plot_title += str(count_non_zero_values_in_dictionary) + " detected classes)"
    # end Plot title
    x_label = "Number of objects per class"
    output_path = results_files_path + "/detection-results-info.png"
    to_show = False
    plot_color = 'forestgreen'
    true_p_bar = count_true_positives
    draw_plot_func(
        det_counter_per_class,
        len(det_counter_per_class),
        window_title,
        plot_title,
        x_label,
        output_path,
        to_show,
        plot_color,
        true_p_bar
        )

"""
 Write number of detected objects per class to results.txt
"""
with open(results_files_path + "/results.txt", 'a') as results_file:
    results_file.write("\n# Number of detected objects per class\n")
    for class_name in sorted(dr_classes):
        n_det = det_counter_per_class[class_name]
        text = class_name + ": " + str(n_det)
        text += " (tp:" + str(count_true_positives[class_name]) + ""
        text += ", fp:" + str(n_det - count_true_positives[class_name]) + ")\n"
        results_file.write(text)

"""
 Draw log-average miss rate plot (Show lamr of all classes in decreasing order)
"""
if draw_plot:
    window_title = "lamr"
    plot_title = "log-average miss rate"
    x_label = "log-average miss rate"
    output_path = results_files_path + "/lamr.png"
    to_show = False
    plot_color = 'royalblue'
    draw_plot_func(
        lamr_dictionary,
        n_classes,
        window_title,
        plot_title,
        x_label,
        output_path,
        to_show,
        plot_color,
        ""
        )

"""
 Draw mAP plot (Show AP's of all classes in decreasing order)
"""
if draw_plot:
    window_title = "mAP"
    plot_title = "mAP = {0:.2f}%".format(mAP*100)
    x_label = "Average Precision"
    output_path = results_files_path + "/mAP.png"
    to_show = True
    plot_color = 'royalblue'
    draw_plot_func(
        ap_dictionary,
        n_classes,
        window_title,
        plot_title,
        x_label,
        output_path,
        to_show,
        plot_color,
        ""
        )
# Out:
# usage: ipykernel_launcher.py [-h] [-na] [-np] [-q] [-i IGNORE [IGNORE ...]]
#                              [--set-class-iou SET_CLASS_IOU [SET_CLASS_IOU ...]]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\10902306\AppData\Roaming\jupyter\runtime\kernel-76d6af4d-68a7-43c2-9f29-d2dab04e0849.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
